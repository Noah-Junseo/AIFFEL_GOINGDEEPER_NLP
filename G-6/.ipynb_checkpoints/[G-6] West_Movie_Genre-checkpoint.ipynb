# %% [markdown]
# 프로젝트 : 모든 장르 간 편향성 측정해 보기
# ===
#
# 영화 시놉시스 코퍼스를 가지고 영화 구분과 모든 영화 장르 간에 내재된 편향성을 측정하는 작업을 진행해 보겠습니다.
#
#
# - WEAT(Word Embedding Association Test)
#     워드 임베딩에 내포된 편향성을 정량적으로 측정하는 방법
#     논문 : https://arxiv.org/pdf/1608.07187.pdf
#
#
# [ 목차 ]
# 1. 형태소 분석기를 이용하여 품사가 명사인 경우 해당 단어를 추출하기
# 2. 추출된 결과로 embedding model 만들기
# 3. target, attribute 단어 셋 만들기
# 4. WEAT score 계산과 시각화

# %% [markdown]
# ## 1. 형태소 분석기를 이용하여 품사가 명사인 경우 해당 단어를 추출하기
#
# synopsis.txt(대략 17MB)에는 2001년부터 2019년 8월까지 제작된 영화들의 시놉시스 정보가 있습니다. (개봉된 영화 중 일부만 포함되어있습니다. 더 많은 영화 정보는 KOBIS에서 확인 가능합니다.) synopsis.txt의 일부를 읽어봅니다.

# %%
# 항상 하는 미친짓 ^^ 
import time
start_time = time.time()

# %%
import os

with open('C:/Users/Noah/aiffel/GoingDeeper/AIFFEL_GOINGDEEPER_NLP/G-6/data/synopsis.txt', 'r', encoding='utf8') as file:
    for i in range(10):
        print(file.readline(), end='')
# Out:
# 사운드 엔지니어 상우(유지태 분)는 치매에 걸린 할머니(백성희 분)와
#  젊은 시절 상처한 한 아버지(박인환 분), 고모(신신애 분)와 함께 살고 있다.
#  어느 겨울 그는 지방 방송국 라디오 PD 은수(이영애 분)를 만난다.
#  자연의 소리를 채집해 틀어주는 라디오 프로그램을 준비하는 은수는 상우와 녹음 여행을 떠난다.
#  자연스레 가까워지는 두 사람은 어느 날, 은수의 아파트에서 밤을 보낸다.
#  너무 쉽게 사랑에 빠진 두 사람... 상우는 주체할 수 없을 정도로 그녀에게 빨려든다.
#  그러나 겨울에 만난 두 사람의 관계는 봄을 지나 여름을 맞이하면서 삐걱거린다.
#  이혼 경험이 있는 은수는 상우에게 결혼할 생각이 없다며 부담스러운 표정을 내비친다.
#  "어떻게 사랑이 변하니?..."라고 묻는 상우에게 은수는 그저 "헤어져" 라고 단호하게 말한다.
#  영원히 변할 것 같지 않던 사랑이 변하고, 그 사실을 받아들이지 못하는 상우는 어찌 할 바를 모른다.

# %% [markdown]
# 이제 synopsis.txt 파일을 읽어 품사가 명사인 경우만 남겨 tokenized라는 변수명으로 저장해봅니다. konlpy 패키지를 이용해봅니다.

# %%
# 약 15분정도 걸립니다.
from konlpy.tag import Okt

os.environ['JAVA_HOME'] = r'C:\Program Files\Java\jdk-17.0.2' #윈도우 로컬에서 환경변수를 제대로 설정해도 안될경우 사용
okt = Okt()
tokenized = []
with open('C:/Users/Noah/aiffel/GoingDeeper/AIFFEL_GOINGDEEPER_NLP/G-6/data/synopsis.txt', 'r', encoding='utf8') as file:
    while True:
        line = file.readline()
        if not line: break
        words = okt.pos(line, stem=True, norm=True)
        res = []
        for w in words:
            if w[1] in ["Noun"]:     # "Adjective", "Verb" 등을 포함할 수도 있습니다
                res.append(w[0])     # 명사("Noun")일 때만 tokenized 에 저장
        tokenized.append(res)

# %% [markdown]
# - class konlpy.tag.\_okt.Okt
#     okt.pos() : Part of Speech, POS (품사) tagger
#     - stem=True : stem tokens
#     - norm=True : normalize tokens
#     https://konlpy.org/en/latest/api/konlpy.tag/#okt-class

# %%
print(len(tokenized))
# Out:
# 71156

# %% [markdown]
# # 2. 추출된 결과로 embedding model 만들기

# %%
from gensim.models import Word2Vec

# tokenized에 담긴 데이터를 가지고 Word2Vec을 생성 (Gensim 4.0 기준)
model = Word2Vec(tokenized, vector_size=100, window=5, min_count=3, sg=0)  
model.wv.most_similar(positive=['영화'])
# Out:
# [('작품', 0.874407172203064),
#  ('다큐멘터리', 0.8312727808952332),
#  ('드라마', 0.8150084614753723),
#  ('영화로', 0.7807676196098328),
#  ('형식', 0.7764759659767151),
#  ('소재', 0.7699062824249268),
#  ('코미디', 0.7686424255371094),
#  ('감동', 0.7586859464645386),
#  ('주제', 0.751847505569458),
#  ('편의', 0.7418814897537231)]

# %% [markdown]
# - Word2Vec()
#     vector size : 학습 후 임베딩 벡터의 차원
#     window : 컨텍스트 윈도우 크기
#     min_count : 단어 최소 빈도수 제한
#     sg : 0은 CBoW, 1은 Skip-gram
#     https://radimrehurek.com/gensim/models/word2vec.html

# %%
model.wv.most_similar(positive=['사랑'])
# Out:
# [('애정', 0.7037314772605896),
#  ('행복', 0.6995149254798889),
#  ('첫사랑', 0.6952442526817322),
#  ('이별', 0.6926268935203552),
#  ('만남', 0.6924014687538147),
#  ('아르튬', 0.6849116086959839),
#  ('진심', 0.6816758513450623),
#  ('가슴', 0.6809808015823364),
#  ('연애', 0.6740172505378723),
#  ('존경심', 0.6652270555496216)]

# %%
model.wv.most_similar(positive=['연극'])
# Out:
# [('영화감독', 0.9011421799659729),
#  ('시나리오', 0.8758761882781982),
#  ('팬', 0.8751124143600464),
#  ('대본', 0.8723393082618713),
#  ('각색', 0.8705826997756958),
#  ('오페라', 0.8683193325996399),
#  ('예술가', 0.8665006160736084),
#  ('감성', 0.8651681542396545),
#  ('배우', 0.8647565245628357),
#  ('캐스팅', 0.8612452149391174)]

# %% [markdown]
# - Word2Vec가 잘 훈련된 것을 볼 수 있습니다.

# %% [markdown]
# # 3. target, attribute 단어 셋 만들기
#
# TF-IDF로 해당 데이터를 가장 잘 표현하는 단어 셋을 만들어 보겠습니다.
# WEAT score를 구할 때 단어 셋을 만들어주어야 합니다. 두 축을 어떤 기준으로 잡고, 해당 축의 어떤 항목을 사용할지 정해야 합니다.
#
# 여기서는 두 축을 영화 장르, 영화 구분 정보를 이용하겠습니다. (영화 구분 정보란 일반영화, 예술영화, 독립영화로 구분된 정보입니다. KOBIS에서 제공한 정보를 기준으로 분류하였습니다.)
#
# - 영화 구분
#     synopsis_art.txt : 예술영화, synopsis_gen.txt : 일반영화(상업영화), 그 외는 독립영화 등으로 분류됩니다.
# - 장르 구분
#     synopsis_SF.txt: SF, synopsis_family.txt: 가족, synopsis_show.txt: 공연, synopsis_horror.txt: 공포(호러), synopsis_etc.txt: 기타, synopsis_documentary.txt: 다큐멘터리, synopsis_drama.txt: 드라마, synopsis_romance.txt: 멜로로맨스, synopsis_musical.txt: 뮤지컬, synopsis_mystery.txt: 미스터리, synopsis_crime.txt: 범죄, synopsis_historical.txt: 사극, synopsis_western.txt: 서부극(웨스턴), synopsis_adult.txt: 성인물(에로), synopsis_thriller.txt: 스릴러, synopsis_animation.txt: 애니메이션, synopsis_action.txt: 액션, synopsis_adventure.txt: 어드벤처, synopsis_war.txt: 전쟁, synopsis_comedy.txt: 코미디, synopsis_fantasy.txt: 판타지
#
# 예술영화와 일반영화(상업영화)라는 영화구분을 target으로 삼고, 장르구분을 attribute로 삼아 WEAT score를 계산해 보겠습니다.
# ex) 드라마 장르에는 예술영화적 성격이 강하고, 액션 장르에는 일반(상업)영화적 성격이 강할 것이라는 편향성이 워드 임베딩 상에 얼마나 나타나고 있는지를 측정해 봅니다.

# %% [markdown]
# ## target 단어 셋 만들기
#
# 'synopsis_art.txt', 'synopsis_gen.txt' 두 파일을 읽고, 명사에 대해서만 추출하여 art, gen 변수에 할당합니다.

# %%
import os
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from konlpy.tag import Okt

art_txt = 'synopsis_art.txt'
gen_txt = 'synopsis_gen.txt'

# %%
def read_token(file_name):
    okt = Okt()
    result = []
    with open('C:/Users/Noah/aiffel/GoingDeeper/AIFFEL_GOINGDEEPER_NLP/G-6/data/'+file_name, 'r', encoding='utf8') as fread: 
        print(file_name, '파일을 읽고 있습니다.')
        while True:
            line = fread.readline() 
            if not line: break 
            tokenlist = okt.pos(line, stem=True, norm=True) 
            for word in tokenlist:
                if word[1] in ["Noun"]:#, "Adjective", "Verb"]:
                    result.append((word[0])) 
    return ' '.join(result)

# %%
art = read_token(art_txt)
gen = read_token(gen_txt)
# Out:
# synopsis_art.txt 파일을 읽고 있습니다.
# synopsis_gen.txt 파일을 읽고 있습니다.

# %% [markdown]
# WEAT 계산을 위해서는 총 4개의 단어 셋 X, Y, A, B가 필요합니다.
# ex) 예술영화라는 개념을 가장 잘 대표하는 단어들을 art_txt를 처리해서 만든 art라는 단어 리스트에서 골라냅니다.
#
# 이를 위해서 상식을 동원해서 적절한 단어를 골라낼 수도 있지만 보다 납득할 수 있는 보편적인 방법을 사용하는 것이 좋습니다.
# 예술영화, 일반영화라는 영화 구분별로 시놉시스를 모아 데이터를 구성했습니다. 그렇다면 예술영화를 잘 대표하는 단어란 예술영화 시놉시스에는 자주 나타나지만 그 외 다른 구분의 영화(예를 들어 일반영화) 시놉시스에는 자주 나타나지 않는 것을 고르는 것이 적당합니다.
#
# 이런 것과 비슷한 개념의 단어 분석 방식 중, TF-IDF 방식을 사용해 봅니다.
# 코퍼스에서 자주 나타나는(TF가 높은) 단어이지만, 다른 코퍼스에까지 두루 걸쳐 나오지는 않는(IDF가 높은) 단어를 선정합니다.
#
# - TF-IDF : https://ko.wikipedia.org/wiki/Tf-idf

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([art, gen])

print(X.shape)
# Out:
# (2, 41082)

# %% [markdown]
# - sklearn.feature_extraction.text.TfidfVectorizer : Convert a collection of raw documents to a matrix of TF-IDF features
#     https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
# - .fit_transform(raw_documents) : Learn vocabulary and idf, return document-term matrix
# - vocabulary_ : (attribute) dict, A mapping of terms to feature indices.
# - .get_feature_names() : Array mapping from feature integer indices to feature name

# %%
print(vectorizer.vocabulary_['영화'])
print(vectorizer.get_feature_names()[23976])
# Out:
# 23976
# 영화
# C:\Users\Noah\anaconda3\envs\Aiffel2\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
m1 = X[0].tocoo()   # art를 TF-IDF로 표현한 sparse matrix를 가져오기 
m2 = X[1].tocoo()   # gen을 TF-IDF로 표현한 sparse matrix를 가져오기 

w1 = [[i, j] for i, j in zip(m1.col, m1.data)]
w2 = [[i, j] for i, j in zip(m2.col, m2.data)]

w1.sort(key=lambda x: x[1], reverse=True)   # art를 구성하는 단어들을 TF-IDF가 높은 순으로 정렬 
w2.sort(key=lambda x: x[1], reverse=True)   # gen을 구성하는 단어들을 TF-IDF가 높은 순으로 정렬

# %%
print(m1)
# Out:
#   (0, 24288)	0.0001813433827312183
#   (0, 30456)	0.0001813433827312183
#   (0, 11824)	0.00025487179701503193
#   (0, 20957)	0.00025487179701503193
#   (0, 23539)	0.0001813433827312183
#   (0, 15055)	0.0005440301481936549
#   (0, 22947)	0.00025487179701503193
#   (0, 19974)	0.0001813433827312183
#   (0, 22314)	0.0001813433827312183
#   (0, 36911)	0.0005097435940300639
#   (0, 36545)	0.0001813433827312183
#   (0, 16222)	0.00025487179701503193
#   (0, 870)	0.0001813433827312183
#   (0, 10861)	0.0001813433827312183
#   (0, 22324)	0.0001813433827312183
#   (0, 5551)	0.0001813433827312183
#   (0, 14795)	0.0001813433827312183
#   (0, 17245)	0.0001813433827312183
#   (0, 7774)	0.0001813433827312183
#   (0, 36535)	0.00025487179701503193
#   (0, 6081)	0.0001813433827312183
#   (0, 17587)	0.0001813433827312183
#   (0, 33441)	0.0001813433827312183
#   (0, 23952)	0.0001813433827312183
#   (0, 3794)	0.0007646153910450958
#   :	:
#   (0, 5484)	0.0023574639755058377
#   (0, 30736)	0.03717539345989975
#   (0, 37858)	0.00743507869197995
#   (0, 32086)	0.0003626867654624366
#   (0, 18416)	0.0148701573839599
#   (0, 28257)	0.010155229432948224
#   (0, 27166)	0.0001813433827312183
#   (0, 26500)	0.0010880602963873097
#   (0, 8220)	0.0063470183955926405
#   (0, 13322)	0.0027201507409682743
#   (0, 31138)	0.0063470183955926405
#   (0, 1222)	0.010336572815679443
#   (0, 20672)	0.00025487179701503193
#   (0, 1682)	0.0029014941236994926
#   (0, 12890)	0.0003626867654624366
#   (0, 21403)	0.09502393255115839
#   (0, 17008)	0.03082837506430711
#   (0, 20436)	0.02756419417514518
#   (0, 13570)	0.0001813433827312183
#   (0, 38818)	0.03064703168157589
#   (0, 33282)	0.004533584568280458
#   (0, 26211)	0.0003626867654624366
#   (0, 16979)	0.003989554420086802
#   (0, 23276)	0.0007253735309248732
#   (0, 16393)	0.002538807358237056

# %% [markdown]
# - scipy.sparse.csc_matrix.tocoo() : Return a COOrdinate representation of this matrix
#     https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.sparse.csc_matrix.tocoo.html

# %%
print('예술영화를 대표하는 단어들:')
for i in range(100):
    print(vectorizer.get_feature_names()[w1[i][0]], end=', ')

print('\n')
    
print('일반영화를 대표하는 단어들:')
for i in range(100):
    print(vectorizer.get_feature_names()[w2[i][0]], end=', ')
# Out:
# 예술영화를 대표하는 단어들:
# 그녀, 자신, 시작, 위해, 사랑, 사람, 영화, 친구, 남자, 가족, 이야기, 마을, 사건, 마음, 세상, 아버지, 아이, 엄마, 모든, 여자, 대한, 서로, 과연, 다시, 시간, 아들, 소녀, 아내, 다른, 사이, 영화제, 세계, 사실, 하나, 점점, 남편, 감독, 여행, 인생, 발견, 모두, 순간, 우리, 가장, 마지막, 생활, 아빠, 모습, 통해, 죽음, 기억, 비밀, 학교, 음악, 한편, 소년, 생각, 도시, 명의, 사고, 결혼, 전쟁, 때문, 위기, 이제, 최고, 이자, 과거, 일상, 경찰, 상황, 간다, 미국, 결심, 운명, 현실, 관계, 지금, 단편, 여인, 하루, 이름, 이후, 준비, 인간, 감정, 만난, 국제, 처음, 충격, 살인, 누구, 동안, 존재, 그린, 어머니, 연인, 계속, 동생, 작품,
#
# 일반영화를 대표하는 단어들:
# 자신, 그녀, 영화제, 위해, 사람, 시작, 국제, 영화, 친구, 사랑, 남자, 이야기, 대한, 서울, 여자, 사건, 남편, 아이, 가족, 아버지, 다른, 마을, 시간, 엄마, 아들, 모든, 단편, 마음, 사실, 다시, 세계, 모습, 작품, 통해, 생각, 서로, 세상, 발견, 감독, 아내, 관계, 소녀, 사이, 하나, 우리, 애니메이션, 때문, 여성, 죽음, 과연, 점점, 인간, 생활, 한편, 결혼, 상황, 모두, 기억, 명의, 소년, 여행, 가장, 간다, 순간, 이제, 도시, 비밀, 학교, 과거, 가지, 이자, 경찰, 마지막, 미국, 동안, 전쟁, 주인공, 대해, 존재, 현실, 연출, 사고, 살인, 일상, 어머니, 계속, 사회, 인생, 다큐멘터리, 부문, 섹스, 최고, 바로, 동생, 의도, 하루, 위기, 계획, 정체, 한국,

# %% [markdown]
# - 두 개념을 대표하는 단어를 TF-IDF가 높은 순으로 추출하고 싶었는데, 양쪽에 중복된 단어가 너무 많은 것을 볼 수 있습니다.
#
# 두 개념축이 대조되도록 대표하는 단어 셋을 만들고 싶기 때문에 단어가 서로 중복되지 않게 단어셋을 추출해야 합니다. 우선 상위 100개의 단어들 중 중복되는 단어를 제외하고 상위 n(=15)개의 단어를 추출합니다.

# %%
n = 15
w1_, w2_ = [], []
for i in range(100):
    w1_.append(vectorizer.get_feature_names()[w1[i][0]])
    w2_.append(vectorizer.get_feature_names()[w2[i][0]])

# w1에만 있고 w2에는 없는, 예술영화를 잘 대표하는 단어 15개 추출
target_art, target_gen = [], []
for i in range(100):
    if (w1_[i] not in w2_) and (w1_[i] in model.wv): target_art.append(w1_[i])
    if len(target_art) == n: break 

# w2에만 있고 w1에는 없는, 일반영화를 잘 대표하는 단어 15개 추출
for i in range(100):
    if (w2_[i] not in w1_) and (w2_[i] in model.wv): target_gen.append(w2_[i])
    if len(target_gen) == n: break

# %% [markdown]
# 추출된 단어를 살펴봅니다.

# %%
print('예술영화를 대표하는 단어들: ', target_art)
print('일반영화를 대표하는 단어들: ', target_gen)
# Out:
# 예술영화를 대표하는 단어들:  ['아빠', '음악', '결심', '운명', '지금', '여인', '이름', '이후', '준비', '감정', '만난', '처음', '충격', '누구', '그린']
# 일반영화를 대표하는 단어들:  ['서울', '애니메이션', '여성', '가지', '주인공', '대해', '연출', '사회', '다큐멘터리', '부문', '섹스', '바로', '의도', '계획', '정체']

# %% [markdown]
# ## attribute단어 셋 만들기
#
# 여러 장르의 파일을 읽고, 명사에 대해서만 추출하여 봅니다.

# %%
genre_txt = ['synopsis_SF.txt', 'synopsis_family.txt', 'synopsis_show.txt', 'synopsis_horror.txt', 'synopsis_etc.txt', 
             'synopsis_documentary.txt', 'synopsis_drama.txt', 'synopsis_romance.txt', 'synopsis_musical.txt', 
             'synopsis_mystery.txt', 'synopsis_crime.txt', 'synopsis_historical.txt', 'synopsis_western.txt', 
             'synopsis_adult.txt', 'synopsis_thriller.txt', 'synopsis_animation.txt', 'synopsis_action.txt', 
             'synopsis_adventure.txt', 'synopsis_war.txt', 'synopsis_comedy.txt', 'synopsis_fantasy.txt']
genre_name = ['SF', '가족', '공연', '공포(호러)', '기타', '다큐멘터리', '드라마', '멜로로맨스', '뮤지컬', '미스터리', '범죄', '사극', '서부극(웨스턴)',
         '성인물(에로)', '스릴러', '애니메이션', '액션', '어드벤처', '전쟁', '코미디', '판타지']

# %%
genre = []
for file_name in genre_txt:
    genre.append(read_token(file_name))
# Out:
# synopsis_SF.txt 파일을 읽고 있습니다.
# synopsis_family.txt 파일을 읽고 있습니다.
# synopsis_show.txt 파일을 읽고 있습니다.
# synopsis_horror.txt 파일을 읽고 있습니다.
# synopsis_etc.txt 파일을 읽고 있습니다.
# synopsis_documentary.txt 파일을 읽고 있습니다.
# synopsis_drama.txt 파일을 읽고 있습니다.
# synopsis_romance.txt 파일을 읽고 있습니다.
# synopsis_musical.txt 파일을 읽고 있습니다.
# synopsis_mystery.txt 파일을 읽고 있습니다.
# synopsis_crime.txt 파일을 읽고 있습니다.
# synopsis_historical.txt 파일을 읽고 있습니다.
# synopsis_western.txt 파일을 읽고 있습니다.
# synopsis_adult.txt 파일을 읽고 있습니다.
# synopsis_thriller.txt 파일을 읽고 있습니다.
# synopsis_animation.txt 파일을 읽고 있습니다.
# synopsis_action.txt 파일을 읽고 있습니다.
# synopsis_adventure.txt 파일을 읽고 있습니다.
# synopsis_war.txt 파일을 읽고 있습니다.
# synopsis_comedy.txt 파일을 읽고 있습니다.
# synopsis_fantasy.txt 파일을 읽고 있습니다.

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(genre)

print(X.shape)
# Out:
# (21, 42191)

# %%
m = [X[i].tocoo() for i in range(X.shape[0])] # TF-IDF로 표현한 sparse matrix를 가져오기

w = [[[i, j] for i, j in zip(mm.col, mm.data)] for mm in m]

for i in range(len(w)): # 구성하는 단어들을 TF-IDF가 높은 순으로 정렬
    w[i].sort(key=lambda x: x[1], reverse=True)

# %%
# 상위 15개 까지만 추출된 단어를 살펴봅니다.
attributes = []
for i in range(len(w)):
    print(genre_name[i], end=': ')
    attr = []
    j = 0
    while (len(attr) < 15):
        if vectorizer.get_feature_names()[w[i][j][0]] in model.wv:
            attr.append(vectorizer.get_feature_names()[w[i][j][0]])
            print(vectorizer.get_feature_names()[w[i][j][0]], end=', ')
        j += 1
    attributes.append(attr)
    print()
# Out:
# SF: 위해, 자신, 지구, 시작, 사람, 인류, 인간, 미래, 우주, 그녀, 로봇, 세계, 모든, 박사, 우주선,
# 가족: 엄마, 아빠, 가족, 영화제, 자신, 위해, 친구, 아주르, 아버지, 시작, 그녀, 아들, 마을, 국제, 낙타,
# 공연: 오페라, 사랑, 토스카, 실황, 올레, 자신, 카바, 그녀, 공연, 오텔로, 리골레토, 백작, 프레, 베르디, 위해,
# 공포(호러): 시작, 위해, 사람, 자신, 친구, 그녀, 사건, 공포, 발견, 죽음, 마을, 가족, 악령, 남자, 좀비,
# 기타: 영화제, 국제, 서울, 단편, 영화, 자신, 사람, 이야기, 그녀, 남자, 위해, 시작, 사랑, 뉴미디어, 페스티벌,
# 다큐멘터리: 영화제, 영화, 다큐, 국제, 다큐멘터리, 사람, 이야기, 대한, 자신, 감독, 위해, 서울, 우리, 시작, 세계,
# 드라마: 자신, 영화제, 그녀, 사람, 사랑, 영화, 위해, 시작, 국제, 남자, 친구, 이야기, 엄마, 여자, 아버지,
# 멜로로맨스: 그녀, 사랑, 자신, 시작, 남편, 남자, 여자, 사람, 친구, 섹스, 위해, 마음, 결혼, 서로, 아내,
# 뮤지컬: 뮤지컬, 사랑, 에스메랄다, 그녀, 음악, 충무로, 모차르트, 영화, 토스카, 자신, 니웨, 카바, 영화제, 바흐, 페뷔스,
# 미스터리: 사건, 그녀, 시작, 자신, 위해, 사람, 발견, 사고, 진실, 죽음, 기억, 살인, 친구, 아내, 남자,
# 범죄: 사건, 위해, 자신, 경찰, 시작, 그녀, 범죄, 조직, 살인, 사람, 마약, 형사, 남자, 모든, 살해,
# 사극: 조선, 위해, 시작, 신기전, 사랑, 자신, 아가멤논, 황제, 그녀, 루안, 최고, 운명, 사람, 하선, 전쟁,
# 서부극(웨스턴): 서부, 보안관, 위해, 벌린, 카우보이, 그레이프바인, 헨리, 마을, 자신, 개릿, 아이, 시작, 무법자, 프린트, 마적,
# 성인물(에로): 그녀, 남편, 마사지, 자신, 섹스, 관계, 영화, 정사, 남자, 위해, 시작, 여자, 유부녀, 마음, 사랑,
# 스릴러: 자신, 그녀, 사건, 시작, 위해, 사람, 살인, 남자, 발견, 아내, 경찰, 친구, 모든, 사실, 살해,
# 애니메이션: 애니메이션, 국제, 영화제, 친구, 인디애니페스트, 위해, 자신, 시작, 사람, 페스티벌, 서울, 이야기, 아이, 마을, 소녀,
# 액션: 위해, 자신, 시작, 조직, 사건, 사람, 그녀, 경찰, 전쟁, 모든, 목숨, 사실, 친구, 가족, 요원,
# 어드벤처: 위해, 자신, 시작, 친구, 마을, 아버지, 영화, 아이, 사람, 여행, 세계, 앤트, 세상, 가족, 모험,
# 전쟁: 전쟁, 독일군, 전투, 위해, 작전, 시작, 부대, 윈터스, 독일, 연합군, 미군, 임무, 자신, 사람, 나치,
# 코미디: 그녀, 자신, 시작, 위해, 사랑, 사람, 친구, 영화, 남자, 여자, 영화제, 가족, 과연, 마을, 사건,
# 판타지: 자신, 그녀, 시작, 위해, 사람, 사랑, 요괴, 영화제, 이야기, 영화, 소녀, 남자, 인간, 세상, 마을,

# %% [markdown]
# - 각 장르를 대표하는 단어들을 추출해보았습니다. 중복된 것이 종종 있지만 art, gen 두 개의 단어 셋을 추출했을 때에 비해 적습니다. 그러므로 중복을 체크해서 삭제하기보다 그대로 사용합니다.

# %% [markdown]
# # 4. WEAT score 계산과 시각화
#
# 영화 구분, 영화 장르에 따른 편향성을 측정하여 WEAT score로 계산해 보고 이를 Heatmap 형태로 시각화해 봅니다.

# %% [markdown]
# ## WEAT score 계산
#
# WEAT score는 다음과 같이 정의합니다.
# ![image.png](attachment:image.png)
#
# - 이 테스트는 두 벡터의 유사도를 측정하기 위해 cosine similarity를 이용합니다. cosine similarity는 두 벡터 사이의 cosine 값을 이용하여 두 벡터의 유사도를 측정합니다. 다시 말해, 두 벡터 i,j가 주어졌을 때, cosine similarity cos(θ)는 dot product와 magnitude를 사용하여 구할 수 있습니다. cosine similarity는 -1에서 1을 가질 수 있으며 두 벡터의 방향이 얼마나 유사한지를 나타내게 됩니다.
# - s(w,A,B)가 의미하는 것은 target에 있는 단어 w가 두 attribute 셋 A, B에 속한 단어들과의 유사도의 평균(mean)값이 얼마나 차이 나는지를 측정합니다. 즉, s(w,A,B)는 개별 단어 w가 개념축 A-B에 대해 가지는 편향성을 계산한 값이 됩니다. 이 편향성 값은 -2에서 2사이의 값을 가지게 되며, 그 절댓값이 클수록 w는 A-B 개념축에 대해 편향성을 가진다는 뜻이 됩니다.
# - 분자 부분은 target X, Y에 속하는 각 단어 x, y들이 개념축 A-B에 대해 가지는 편향성을 r각각 평균 내서 뺀 차이입니다. 즉, X에 속하는 단어들과 Y에 속하는 단어들이 A-B 개념축에 대해 가지는 편향성의 정도가 뚜렷이 차이 날수록 이 WEAT score 식의 분자값의 절댓값은 커지게 됩니다. 이 값을 X, Y에 속하는 모든 단어들이 가지는 편향성 값의 표준편차(std)로 normalize한 값이 최종 WEAT score가 됩니다.

# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

# %%
def cos_sim(i, j):
    return dot(i, j.T)/(norm(i)*norm(j))

def s(w, A, B):
    c_a = cos_sim(w, A)
    c_b = cos_sim(w, B)
    mean_A = np.mean(c_a, axis=-1)
    mean_B = np.mean(c_b, axis=-1)
    return mean_A - mean_B #, c_a, c_b

# %%
def weat_score(X, Y, A, B):
    
    s_X = s(X, A, B)
    s_Y = s(Y, A, B)

    mean_X = np.mean(s_X)
    mean_Y = np.mean(s_Y)
    
    std_dev = np.std(np.concatenate([s_X, s_Y], axis=0))
    
    return  (mean_X-mean_Y)/std_dev

# %% [markdown]
# 이제 WEAT_score를 구해봅니다.
#
# target_X 는 art, target_Y 는 gen으로 고정하고 attribute_A, attribute_B를 바꿔가면서 구해봅니다. 구한 결과를 21x21 매트릭스 형태로 표현해서 matrix 라는 변수에 담아봅니다.

# %%
matrix = [[0 for _ in range(len(genre_name))] for _ in range(len(genre_name))]
print(len(matrix))
# Out:
# 21

# %%
X = np.array([model.wv[word] for word in target_art])
Y = np.array([model.wv[word] for word in target_gen])

for i in range(len(genre_name)-1):
    for j in range(i+1, len(genre_name)):
        A = np.array([model.wv[word] for word in attributes[i]])
        B = np.array([model.wv[word] for word in attributes[j]])
        matrix[i][j] = weat_score(X, Y, A, B)

# %% [markdown]
# - matrix를 채워보았습니다. WEAT score 값을 보고, 편향성을 살펴봅니다.

# %%
for i in range(len(genre_name)-1):
    for j in range(i+1, len(genre_name)):
        print(genre_name[i], genre_name[j], matrix[i][j])
# Out:
# SF 가족 -0.55036455
# SF 공연 -0.38375363
# SF 공포(호러) -0.7105562
# SF 기타 0.3109172
# SF 다큐멘터리 0.576735
# SF 드라마 -0.42326772
# SF 멜로로맨스 -0.802604
# SF 뮤지컬 0.33205354
# SF 미스터리 -0.71594036
# SF 범죄 -0.25311196
# SF 사극 -0.8106051
# SF 서부극(웨스턴) -0.4455621
# SF 성인물(에로) -0.59545416
# SF 스릴러 -0.54308724
# SF 애니메이션 0.32057375
# SF 액션 -0.46779343
# SF 어드벤처 -0.82384014
# SF 전쟁 0.21308003
# SF 코미디 -0.4858207
# SF 판타지 -0.23938058
# 가족 공연 0.2383295
# 가족 공포(호러) -0.15351336
# 가족 기타 0.7609124
# 가족 다큐멘터리 0.8469898
# 가족 드라마 0.22229137
# 가족 멜로로맨스 -0.61514246
# 가족 뮤지컬 0.7336448
# 가족 미스터리 -0.30402458
# 가족 범죄 0.24088366
# 가족 사극 -0.006728463
# 가족 서부극(웨스턴) 0.4709734
# 가족 성인물(에로) -0.3183566
# 가족 스릴러 -0.114372544
# 가족 애니메이션 0.87040937
# 가족 액션 0.15623441
# 가족 어드벤처 0.03551531
# 가족 전쟁 0.6683429
# 가족 코미디 0.2234683
# 가족 판타지 0.44703808
# 공연 공포(호러) -0.27889192
# 공연 기타 0.91373
# 공연 다큐멘터리 0.9188009
# 공연 드라마 -0.07400277
# 공연 멜로로맨스 -0.733212
# 공연 뮤지컬 0.8978626
# 공연 미스터리 -0.3871348
# 공연 범죄 0.07323728
# 공연 사극 -0.36543867
# 공연 서부극(웨스턴) 0.037856076
# 공연 성인물(에로) -0.5223201
# 공연 스릴러 -0.23091586
# 공연 애니메이션 0.87481415
# 공연 액션 -0.028084783
# 공연 어드벤처 -0.22097395
# 공연 전쟁 0.5972057
# 공연 코미디 -0.04300859
# 공연 판타지 0.29855222
# 공포(호러) 기타 0.6442985
# 공포(호러) 다큐멘터리 0.75618255
# 공포(호러) 드라마 0.30555603
# 공포(호러) 멜로로맨스 -0.61790454
# 공포(호러) 뮤지컬 0.63735944
# 공포(호러) 미스터리 -0.59602803
# 공포(호러) 범죄 0.72617644
# 공포(호러) 사극 0.1759526
# 공포(호러) 서부극(웨스턴) 0.4555886
# 공포(호러) 성인물(에로) -0.23022436
# 공포(호러) 스릴러 0.04242434
# 공포(호러) 애니메이션 0.66042006
# 공포(호러) 액션 0.6336718
# 공포(호러) 어드벤처 0.22159174
# 공포(호러) 전쟁 0.6785479
# 공포(호러) 코미디 0.4586816
# 공포(호러) 판타지 0.5443671
# 기타 다큐멘터리 0.6010623
# 기타 드라마 -0.8989523
# 기타 멜로로맨스 -0.8968224
# 기타 뮤지컬 0.0788421
# 기타 미스터리 -0.66765827
# 기타 범죄 -0.37312183
# 기타 사극 -0.8224804
# 기타 서부극(웨스턴) -0.60793376
# 기타 성인물(에로) -0.82196915
# 기타 스릴러 -0.55897754
# 기타 애니메이션 -0.070682794
# 기타 액션 -0.46379575
# 기타 어드벤처 -0.7894815
# 기타 전쟁 -0.20030856
# 기타 코미디 -0.72829944
# 기타 판타지 -0.6743952
# 다큐멘터리 드라마 -0.9306194
# 다큐멘터리 멜로로맨스 -0.90523744
# 다큐멘터리 뮤지컬 -0.7042417
# 다큐멘터리 미스터리 -0.763045
# 다큐멘터리 범죄 -0.5052184
# 다큐멘터리 사극 -0.91634315
# 다큐멘터리 서부극(웨스턴) -0.7299217
# 다큐멘터리 성인물(에로) -0.84244186
# 다큐멘터리 스릴러 -0.65662134
# 다큐멘터리 애니메이션 -0.5515639
# 다큐멘터리 액션 -0.60371995
# 다큐멘터리 어드벤처 -0.948374
# 다큐멘터리 전쟁 -0.43821284
# 다큐멘터리 코미디 -0.8283091
# 다큐멘터리 판타지 -0.89921045
# 드라마 멜로로맨스 -0.8362054
# 드라마 뮤지컬 0.8622103
# 드라마 미스터리 -0.42588702
# 드라마 범죄 0.10720077
# 드라마 사극 -0.26482227
# 드라마 서부극(웨스턴) 0.09185033
# 드라마 성인물(에로) -0.5900502
# 드라마 스릴러 -0.23240866
# 드라마 애니메이션 0.8849789
# 드라마 액션 0.0034435743
# 드라마 어드벤처 -0.22755253
# 드라마 전쟁 0.5046238
# 드라마 코미디 0.029079374
# 드라마 판타지 0.5524595
# 멜로로맨스 뮤지컬 0.87897563
# 멜로로맨스 미스터리 0.4429994
# 멜로로맨스 범죄 0.86462945
# 멜로로맨스 사극 0.67372787
# 멜로로맨스 서부극(웨스턴) 0.765496
# 멜로로맨스 성인물(에로) 0.80253416
# 멜로로맨스 스릴러 0.6722153
# 멜로로맨스 애니메이션 0.87735885
# 멜로로맨스 액션 0.7601042
# 멜로로맨스 어드벤처 0.6215723
# 멜로로맨스 전쟁 0.811094
# 멜로로맨스 코미디 0.9114618
# 멜로로맨스 판타지 0.8377925
# 뮤지컬 미스터리 -0.6642354
# 뮤지컬 범죄 -0.3727743
# 뮤지컬 사극 -0.82147616
# 뮤지컬 서부극(웨스턴) -0.58768666
# 뮤지컬 성인물(에로) -0.8092503
# 뮤지컬 스릴러 -0.5540364
# 뮤지컬 애니메이션 -0.09885474
# 뮤지컬 액션 -0.4658352
# 뮤지컬 어드벤처 -0.7950959
# 뮤지컬 전쟁 -0.2097714
# 뮤지컬 코미디 -0.7088766
# 뮤지컬 판타지 -0.6883857
# 미스터리 범죄 1.0614852
# 미스터리 사극 0.33620936
# 미스터리 서부극(웨스턴) 0.5438684
# 미스터리 성인물(에로) -0.045499597
# 미스터리 스릴러 0.82662416
# 미스터리 애니메이션 0.6738431
# 미스터리 액션 0.8468734
# 미스터리 어드벤처 0.361857
# 미스터리 전쟁 0.7021411
# 미스터리 코미디 0.5658597
# 미스터리 판타지 0.5928175
# 범죄 사극 -0.28811365
# 범죄 서부극(웨스턴) -0.07688874
# 범죄 성인물(에로) -0.52732944
# 범죄 스릴러 -0.9873124
# 범죄 애니메이션 0.37138614
# 범죄 액션 -0.34420064
# 범죄 어드벤처 -0.2323137
# 범죄 전쟁 0.38153994
# 범죄 코미디 -0.12902027
# 범죄 판타지 0.087001264
# 사극 서부극(웨스턴) 0.3896929
# 사극 성인물(에로) -0.37083122
# 사극 스릴러 -0.12091593
# 사극 애니메이션 0.82079744
# 사극 액션 0.19399804
# 사극 어드벤처 0.053964708
# 사극 전쟁 0.8719301
# 사극 코미디 0.376232
# 사극 판타지 0.64566207
# 서부극(웨스턴) 성인물(에로) -0.475157
# 서부극(웨스턴) 스릴러 -0.34918675
# 서부극(웨스턴) 애니메이션 0.6733604
# 서부극(웨스턴) 액션 -0.08196423
# 서부극(웨스턴) 어드벤처 -0.37525398
# 서부극(웨스턴) 전쟁 0.67772174
# 서부극(웨스턴) 코미디 -0.09387317
# 서부극(웨스턴) 판타지 0.22992417
# 성인물(에로) 스릴러 0.24669884
# 성인물(에로) 애니메이션 0.7685363
# 성인물(에로) 액션 0.4206916
# 성인물(에로) 어드벤처 0.3386929
# 성인물(에로) 전쟁 0.63420475
# 성인물(에로) 코미디 0.6105649
# 성인물(에로) 판타지 0.6474954
# 스릴러 애니메이션 0.5649889
# 스릴러 액션 0.5551558
# 스릴러 어드벤처 0.13987848
# 스릴러 전쟁 0.5913481
# 스릴러 코미디 0.31322643
# 스릴러 판타지 0.39953056
# 애니메이션 액션 -0.47571787
# 애니메이션 어드벤처 -0.8623541
# 애니메이션 전쟁 -0.19704108
# 애니메이션 코미디 -0.7252556
# 애니메이션 판타지 -0.66276217
# 액션 어드벤처 -0.15142043
# 액션 전쟁 0.5499085
# 액션 코미디 0.0073665166
# 액션 판타지 0.21298565
# 어드벤처 전쟁 0.7110964
# 어드벤처 코미디 0.30000967
# 어드벤처 판타지 0.7532123
# 전쟁 코미디 -0.54459953
# 전쟁 판타지 -0.31493762
# 코미디 판타지 0.51691836

# %%
over8 = []
under_8 = []

for i in range(len(genre_name)-1):
    for j in range(i+1, len(genre_name)):
        if matrix[i][j] >= 0.8 : 
            over8.append([i, j, matrix[i][j]])
        if matrix[i][j] <= -0.8 : 
            under_8.append([i, j, matrix[i][j]])

print("[  Over 0.8 : ", len(over8), "  ]")
for i, j, score in over8:
    print(genre_name[i], genre_name[j], score)
print()
print("[  Under -0.8 : ", len(under_8), "  ]")
for i, j, score in under_8:
    print(genre_name[i], genre_name[j], score)
# Out:
# [  Over 0.8 :  20   ]
# 가족 다큐멘터리 0.8469898
# 가족 애니메이션 0.87040937
# 공연 기타 0.91373
# 공연 다큐멘터리 0.9188009
# 공연 뮤지컬 0.8978626
# 공연 애니메이션 0.87481415
# 드라마 뮤지컬 0.8622103
# 드라마 애니메이션 0.8849789
# 멜로로맨스 뮤지컬 0.87897563
# 멜로로맨스 범죄 0.86462945
# 멜로로맨스 성인물(에로) 0.80253416
# 멜로로맨스 애니메이션 0.87735885
# 멜로로맨스 전쟁 0.811094
# 멜로로맨스 코미디 0.9114618
# 멜로로맨스 판타지 0.8377925
# 미스터리 범죄 1.0614852
# 미스터리 스릴러 0.82662416
# 미스터리 액션 0.8468734
# 사극 애니메이션 0.82079744
# 사극 전쟁 0.8719301
#
# [  Under -0.8 :  19   ]
# SF 멜로로맨스 -0.802604
# SF 사극 -0.8106051
# SF 어드벤처 -0.82384014
# 기타 드라마 -0.8989523
# 기타 멜로로맨스 -0.8968224
# 기타 사극 -0.8224804
# 기타 성인물(에로) -0.82196915
# 다큐멘터리 드라마 -0.9306194
# 다큐멘터리 멜로로맨스 -0.90523744
# 다큐멘터리 사극 -0.91634315
# 다큐멘터리 성인물(에로) -0.84244186
# 다큐멘터리 어드벤처 -0.948374
# 다큐멘터리 코미디 -0.8283091
# 다큐멘터리 판타지 -0.89921045
# 드라마 멜로로맨스 -0.8362054
# 뮤지컬 사극 -0.82147616
# 뮤지컬 성인물(에로) -0.8092503
# 범죄 스릴러 -0.9873124
# 애니메이션 어드벤처 -0.8623541

# %% [markdown]
# - WEAT score를 보고 예술영화, 일반영화와 각 장르(A, B) 간의 관계를 볼 수 있습니다.
#     WEAT score가 0.8 이상인 경우 : A장르는 예술영화, B장르는 일반영화와 가깝다
#     WEAT score가 -0.8 이하인 경우 : A장르는 일반영화, B장르는 예술영화와 가깝다 (사람의 편향과는 반대)

# %% [markdown]
# ## WEAT score 시각화
#
# 앞에서 계산한 WEAT score를 Heatmap으로 시각화해 봅니다.

# %%
import matplotlib.font_manager as fm


# 설치된 폰트 출력
font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')

font_list[:]
# Out:
# ['C:\\Windows\\Fonts\\holomdl2.ttf',
#  'C:\\Windows\\Fonts\\TCCM____.TTF',
#  'C:\\WINDOWS\\Fonts\\Limelight-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\PARCHM.TTF',
#  'C:\\WINDOWS\\Fonts\\ARIALN.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_CI.TTF',
#  'C:\\Windows\\Fonts\\YuGothL.ttc',
#  'C:\\Windows\\Fonts\\COOPBL.TTF',
#  'C:\\Windows\\Fonts\\calibrili.ttf',
#  'C:\\Windows\\Fonts\\TCBI____.TTF',
#  'C:\\Windows\\Fonts\\GillSansCondLightNova.ttf',
#  'C:\\Windows\\Fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\lucon.ttf',
#  'C:\\Windows\\Fonts\\upcib.ttf',
#  'C:\\Windows\\Fonts\\ROCKEB.TTF',
#  'C:\\WINDOWS\\Fonts\\SegoeIcons.ttf',
#  'C:\\WINDOWS\\Fonts\\msyhbd.ttc',
#  'C:\\WINDOWS\\Fonts\\raavib.ttf',
#  'C:\\WINDOWS\\Fonts\\LFAXDI.TTF',
#  'C:\\Windows\\Fonts\\gadugib.ttf',
#  'C:\\WINDOWS\\Fonts\\RockwellNova-ExtraBoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\CHILLER.TTF',
#  'C:\\Windows\\Fonts\\OUTLOOK.TTF',
#  'C:\\Windows\\Fonts\\upckb.ttf',
#  'C:\\Windows\\Fonts\\COLONNA.TTF',
#  'C:\\Windows\\Fonts\\tungab.ttf',
#  'C:\\WINDOWS\\Fonts\\estre.ttf',
#  'C:\\Windows\\Fonts\\HTOWERTI.TTF',
#  'C:\\WINDOWS\\Fonts\\phagspa.ttf',
#  'C:\\WINDOWS\\Fonts\\mingliu.ttc',
#  'C:\\Windows\\Fonts\\BIZ-UDGothicB.ttc',
#  'C:\\Windows\\Fonts\\CURLZ___.TTF',
#  'C:\\Windows\\Fonts\\VerdanaPro-LightItalic.ttf',
#  'C:\\Windows\\Fonts\\ROCKI.TTF',
#  'C:\\Windows\\Fonts\\H2SA1M.TTF',
#  'C:\\Windows\\Fonts\\VerdanaPro-CondItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\CascadiaCode.ttf',
#  'C:\\Windows\\Fonts\\STHUPO.TTF',
#  'C:\\Windows\\Fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\aparaji.ttf',
#  'C:\\WINDOWS\\Fonts\\calibrib.ttf',
#  'C:\\Windows\\Fonts\\ROGFonts-Regular.otf',
#  'C:\\Windows\\Fonts\\BOOKOSBI.TTF',
#  'C:\\WINDOWS\\Fonts\\BERNHC.TTF',
#  'C:\\Windows\\Fonts\\VerdanaPro-SemiBold.ttf',
#  'C:\\Windows\\Fonts\\LSANSDI.TTF',
#  'C:\\Windows\\Fonts\\CALIST.TTF',
#  'C:\\WINDOWS\\Fonts\\CabinSketch-Bold.ttf',
#  'C:\\Windows\\Fonts\\ArialNova-Bold.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-CondSemiBold.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-SemiBold.ttf',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\WINDOWS\\Fonts\\PermanentMarker.ttf',
#  'C:\\WINDOWS\\Fonts\\shruti.ttf',
#  'C:\\Windows\\Fonts\\GLECB.TTF',
#  'C:\\WINDOWS\\Fonts\\trebuc.ttf',
#  'C:\\Windows\\Fonts\\SigmarOne-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\simfang.ttf',
#  'C:\\Windows\\Fonts\\verdanab.ttf',
#  'C:\\Windows\\Fonts\\CascadiaCode.ttf',
#  'C:\\WINDOWS\\Fonts\\FZSTK.TTF',
#  'C:\\WINDOWS\\Fonts\\GOUDOSB.TTF',
#  'C:\\Windows\\Fonts\\corbelli.ttf',
#  'C:\\WINDOWS\\Fonts\\NotoSans-Italic.ttf',
#  'C:\\WINDOWS\\Fonts\\segoesc.ttf',
#  'C:\\Windows\\Fonts\\cambriaz.ttf',
#  'C:\\Windows\\Fonts\\upclbi.ttf',
#  'C:\\WINDOWS\\Fonts\\WINGDNG3.TTF',
#  'C:\\Windows\\Fonts\\YuGothB.ttc',
#  'C:\\WINDOWS\\Fonts\\YuGothL.ttc',
#  'C:\\WINDOWS\\Fonts\\LSANSDI.TTF',
#  'C:\\Windows\\Fonts\\Vani.ttf',
#  'C:\\WINDOWS\\Fonts\\upckl.ttf',
#  'C:\\WINDOWS\\Fonts\\PERB____.TTF',
#  'C:\\WINDOWS\\Fonts\\RockwellNova-LightItalic.ttf',
#  'C:\\Windows\\Fonts\\WINGDNG2.TTF',
#  'C:\\Windows\\Fonts\\gulim.ttc',
#  'C:\\Windows\\Fonts\\LeelaUIb.ttf',
#  'C:\\WINDOWS\\Fonts\\Deng.ttf',
#  'C:\\Windows\\Fonts\\VINERITC.TTF',
#  'C:\\WINDOWS\\Fonts\\latha.ttf',
#  'C:\\Windows\\Fonts\\verdanaz.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-CondBold.ttf',
#  'C:\\WINDOWS\\Fonts\\HMFMPYUN.TTF',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-LightItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-BoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\MarcellusSC-Regular.ttf',
#  'C:\\Windows\\Fonts\\FELIXTI.TTF',
#  'C:\\WINDOWS\\Fonts\\RockwellNova-ExtraBold.ttf',
#  'C:\\Windows\\Fonts\\courbi.ttf',
#  'C:\\WINDOWS\\Fonts\\consolab.ttf',
#  'C:\\WINDOWS\\Fonts\\msjh.ttc',
#  'C:\\Windows\\Fonts\\nyala.ttf',
#  'C:\\Windows\\Fonts\\ERASMD.TTF',
#  'C:\\Windows\\Fonts\\PALSCRI.TTF',
#  'C:\\Windows\\Fonts\\NGULIM.TTF',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondBlackItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\FELIXTI.TTF',
#  'C:\\WINDOWS\\Fonts\\simsunb.ttf',
#  'C:\\WINDOWS\\Fonts\\FugazOne-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\LTYPEO.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_BI.TTF',
#  'C:\\Windows\\Fonts\\upcli.ttf',
#  'C:\\Windows\\Fonts\\SegUIVar.ttf',
#  'C:\\WINDOWS\\Fonts\\kalinga.ttf',
#  'C:\\Windows\\Fonts\\dokchamp.ttf',
#  'C:\\Windows\\Fonts\\MOD20.TTF',
#  'C:\\WINDOWS\\Fonts\\ARLRDBD.TTF',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-SemiBold.ttf',
#  'C:\\WINDOWS\\Fonts\\RockwellNovaCond-Italic.ttf',
#  'C:\\WINDOWS\\Fonts\\FRAHVIT.TTF',
#  'C:\\Windows\\Fonts\\BSSYM7.TTF',
#  'C:\\WINDOWS\\Fonts\\UrdType.ttf',
#  'C:\\Windows\\Fonts\\FRADMCN.TTF',
#  'C:\\Windows\\Fonts\\GillSansCondItNova.ttf',
#  'C:\\Windows\\Fonts\\Candarab.ttf',
#  'C:\\Windows\\Fonts\\upcfi.ttf',
#  'C:\\Windows\\Fonts\\georgiab.ttf',
#  'C:\\WINDOWS\\Fonts\\RockwellNova-Light.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-CondLight.ttf',
#  'C:\\Windows\\Fonts\\GillSansLightNova.ttf',
#  'C:\\WINDOWS\\Fonts\\ITCEDSCR.TTF',
#  'C:\\WINDOWS\\Fonts\\upcibi.ttf',
#  'C:\\WINDOWS\\Fonts\\BungeeInline-Regular.ttf',
#  'C:\\Windows\\Fonts\\GillSansCondNova.ttf',
#  'C:\\Windows\\Fonts\\segmdl2.ttf',
#  'C:\\WINDOWS\\Fonts\\BIZ-UDGothicR.ttc',
#  'C:\\Windows\\Fonts\\Gabriola.ttf',
#  'C:\\Windows\\Fonts\\BOD_PSTC.TTF',
#  'C:\\WINDOWS\\Fonts\\consolaz.ttf',
#  'C:\\WINDOWS\\Fonts\\Candarali.ttf',
#  'C:\\Windows\\Fonts\\Candaral.ttf',
#  'C:\\Windows\\Fonts\\upcdbi.ttf',
#  'C:\\Windows\\Fonts\\MTCORSVA.TTF',
#  'C:\\WINDOWS\\Fonts\\upcjl.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-CondBlackItalic.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondRegular.ttf',
#  'C:\\WINDOWS\\Fonts\\PAPYRUS.TTF',
#  'C:\\Windows\\Fonts\\BRLNSB.TTF',
#  'C:\\WINDOWS\\Fonts\\BRITANIC.TTF',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-BoldItalic.ttf',
#  'C:\\Windows\\Fonts\\PLAYBILL.TTF',
#  'C:\\WINDOWS\\Fonts\\aparajbi.ttf',
#  'C:\\Windows\\Fonts\\RockwellNovaCond-Italic.ttf',
#  'C:\\Windows\\Fonts\\GOUDOSB.TTF',
#  'C:\\WINDOWS\\Fonts\\LaoUI.ttf',
#  'C:\\WINDOWS\\Fonts\\msuighur.ttf',
#  'C:\\WINDOWS\\Fonts\\GOUDOS.TTF',
#  'C:\\WINDOWS\\Fonts\\corbelli.ttf',
#  'C:\\Windows\\Fonts\\STXINGKA.TTF',
#  'C:\\Windows\\Fonts\\ARIALNB.TTF',
#  'C:\\WINDOWS\\Fonts\\unispace bd.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-CondRegular.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-Black.ttf',
#  'C:\\Windows\\Fonts\\gishabd.ttf',
#  'C:\\Windows\\Fonts\\ROCKB.TTF',
#  'C:\\WINDOWS\\Fonts\\GillSansCondLightNova.ttf',
#  'C:\\Windows\\Fonts\\H2GPRM.TTF',
#  'C:\\WINDOWS\\Fonts\\FRADMIT.TTF',
#  'C:\\Windows\\Fonts\\OCRAEXT.TTF',
#  'C:\\Windows\\Fonts\\upcdi.ttf',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\WINDOWS\\Fonts\\davidbd.ttf',
#  'C:\\Windows\\Fonts\\Quicksand-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\Inter-Bold-slnt=0.ttf',
#  'C:\\WINDOWS\\Fonts\\Megrim.ttf',
#  'C:\\Windows\\Fonts\\mingliub.ttc',
#  'C:\\Windows\\Fonts\\PRISTINA.TTF',
#  'C:\\WINDOWS\\Fonts\\mangalb.ttf',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-CondRegular.ttf',
#  'C:\\WINDOWS\\Fonts\\simhei.ttf',
#  'C:\\Windows\\Fonts\\comici.ttf',
#  'C:\\Windows\\Fonts\\MATURASC.TTF',
#  'C:\\Windows\\Fonts\\RAVIE.TTF',
#  'C:\\WINDOWS\\Fonts\\calibrii.ttf',
#  'C:\\Windows\\Fonts\\kokilabi.ttf',
#  'C:\\Windows\\Fonts\\trebuc.ttf',
#  'C:\\Windows\\Fonts\\Quicksand-Light.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondSemiBoldItalic.ttf',
#  'C:\\Windows\\Fonts\\upcdl.ttf',
#  'C:\\Windows\\Fonts\\segoeuil.ttf',
#  'C:\\WINDOWS\\Fonts\\KhmerUIb.ttf',
#  'C:\\Windows\\Fonts\\ROCCB___.TTF',
#  'C:\\WINDOWS\\Fonts\\HMFMMUEX.TTC',
#  'C:\\WINDOWS\\Fonts\\ENGR.TTF',
#  'C:\\WINDOWS\\Fonts\\STENCIL.TTF',
#  'C:\\Windows\\Fonts\\H2GTRM.TTF',
#  'C:\\Windows\\Fonts\\GillSansBoNova.ttf',
#  'C:\\WINDOWS\\Fonts\\BKANT.TTF',
#  'C:\\Windows\\Fonts\\UDDigiKyokashoN-R.ttc',
#  'C:\\Windows\\Fonts\\phagspab.ttf',
#  'C:\\WINDOWS\\Fonts\\couri.ttf',
#  'C:\\Windows\\Fonts\\STZHONGS.TTF',
#  'C:\\WINDOWS\\Fonts\\GILC____.TTF',
#  'C:\\WINDOWS\\Fonts\\iskpotab.ttf',
#  'C:\\WINDOWS\\Fonts\\INFROMAN.TTF',
#  'C:\\WINDOWS\\Fonts\\HATTEN.TTF',
#  'C:\\WINDOWS\\Fonts\\BOOKOSI.TTF',
#  'C:\\WINDOWS\\Fonts\\cambria.ttc',
#  'C:\\Windows\\Fonts\\upcjbi.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-CondBoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\kalingab.ttf',
#  'C:\\WINDOWS\\Fonts\\RockwellNovaCond-BoldItalic.ttf',
#  'C:\\Windows\\Fonts\\mangal.ttf',
#  'C:\\WINDOWS\\Fonts\\meiryob.ttc',
#  'C:\\Windows\\Fonts\\comicz.ttf',
#  'C:\\WINDOWS\\Fonts\\SitkaVF-Italic.ttf',
#  'C:\\WINDOWS\\Fonts\\simpo.ttf',
#  'C:\\WINDOWS\\Fonts\\ROCCB___.TTF',
#  'C:\\Windows\\Fonts\\RockwellNova-Bold.ttf',
#  'C:\\Windows\\Fonts\\H2PORM.TTF',
#  'C:\\WINDOWS\\Fonts\\MATURASC.TTF',
#  'C:\\WINDOWS\\Fonts\\HMKMRHD.TTF',
#  'C:\\WINDOWS\\Fonts\\Cinzel-Black.ttf',
#  'C:\\WINDOWS\\Fonts\\tahomabd.ttf',
#  'C:\\Windows\\Fonts\\kalingab.ttf',
#  'C:\\WINDOWS\\Fonts\\gautamib.ttf',
#  'C:\\WINDOWS\\Fonts\\pala.ttf',
#  'C:\\WINDOWS\\Fonts\\Teko-SemiBold.ttf',
#  'C:\\WINDOWS\\Fonts\\BELLI.TTF',
#  'C:\\WINDOWS\\Fonts\\upcll.ttf',
#  'C:\\WINDOWS\\Fonts\\MTCORSVA.TTF',
#  'C:\\WINDOWS\\Fonts\\mangal.ttf',
#  'C:\\WINDOWS\\Fonts\\simpfxo.ttf',
#  'C:\\Windows\\Fonts\\vijayab.ttf',
#  'C:\\WINDOWS\\Fonts\\Courgette-Regular.ttf',
#  'C:\\Windows\\Fonts\\arialbd.ttf',
#  'C:\\WINDOWS\\Fonts\\MontserratSubrayada-Bold.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-BoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\SHOWG.TTF',
#  'C:\\WINDOWS\\Fonts\\cambriaz.ttf',
#  'C:\\Windows\\Fonts\\simhei.ttf',
#  'C:\\Windows\\Fonts\\taileb.ttf',
#  'C:\\WINDOWS\\Fonts\\plantc.ttf',
#  'C:\\WINDOWS\\Fonts\\MISTRAL.TTF',
#  'C:\\Windows\\Fonts\\HMFMOLD.TTF',
#  'C:\\WINDOWS\\Fonts\\GARABD.TTF',
#  'C:\\WINDOWS\\Fonts\\ARIALNI.TTF',
#  'C:\\WINDOWS\\Fonts\\symbol.ttf',
#  'C:\\Windows\\Fonts\\frank.ttf',
#  'C:\\WINDOWS\\Fonts\\upceb.ttf',
#  'C:\\Windows\\Fonts\\CALISTB.TTF',
#  'C:\\Windows\\Fonts\\simpfxo.ttf',
#  'C:\\WINDOWS\\Fonts\\ahronbd.ttf',
#  'C:\\WINDOWS\\Fonts\\OUTLOOK.TTF',
#  'C:\\Windows\\Fonts\\TCCEB.TTF',
#  'C:\\Windows\\Fonts\\GILLUBCD.TTF',
#  'C:\\Windows\\Fonts\\msjh.ttc',
#  'C:\\Windows\\Fonts\\GillSansBoItNova.ttf',
#  'C:\\Windows\\Fonts\\SCHLBKBI.TTF',
#  'C:\\Windows\\Fonts\\STSONG.TTF',
#  'C:\\WINDOWS\\Fonts\\GARAIT.TTF',
#  'C:\\WINDOWS\\Fonts\\cambriai.ttf',
#  'C:\\WINDOWS\\Fonts\\LSANSD.TTF',
#  'C:\\WINDOWS\\Fonts\\CabinSketch-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\upcfb.ttf',
#  'C:\\Windows\\Fonts\\msyhbd.ttc',
#  'C:\\Windows\\Fonts\\ArialNova-LightItalic.ttf',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\GOTHICBI.TTF',
#  'C:\\Windows\\Fonts\\VerdanaPro-CondBlack.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuil.ttf',
#  'C:\\Windows\\Fonts\\LSANS.TTF',
#  'C:\\Windows\\Fonts\\LaoUIb.ttf',
#  'C:\\WINDOWS\\Fonts\\calibrili.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-CondLight.ttf',
#  'C:\\WINDOWS\\Fonts\\AGENCYR.TTF',
#  'C:\\WINDOWS\\Fonts\\LFAXD.TTF',
#  'C:\\Windows\\Fonts\\GillSansCondExtraItNova.ttf',
#  'C:\\WINDOWS\\Fonts\\msyhl.ttc',
#  'C:\\WINDOWS\\Fonts\\NHaasGroteskTXPro-Rg.ttf',
#  'C:\\Windows\\Fonts\\LFAXDI.TTF',
#  'C:\\WINDOWS\\Fonts\\simkai.ttf',
#  'C:\\WINDOWS\\Fonts\\ArialNovaCond-Bold.ttf',
#  'C:\\WINDOWS\\Fonts\\LTYPEB.TTF',
#  'C:\\WINDOWS\\Fonts\\STXINGKA.TTF',
#  'C:\\Windows\\Fonts\\BRITANIC.TTF',
#  'C:\\Windows\\Fonts\\taile.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuiz.ttf',
#  'C:\\Windows\\Fonts\\BIZ-UDGothicR.ttc',
#  'C:\\Windows\\Fonts\\arabtype.ttf',
#  'C:\\Windows\\Fonts\\corbelb.ttf',
#  'C:\\Windows\\Fonts\\STCAIYUN.TTF',
#  'C:\\Windows\\Fonts\\corbel.ttf',
#  'C:\\WINDOWS\\Fonts\\NirmalaS.ttf',
#  'C:\\Windows\\Fonts\\Sanskr.ttf',
#  'C:\\WINDOWS\\Fonts\\upckb.ttf',
#  'C:\\Windows\\Fonts\\arialbi.ttf',
#  'C:\\WINDOWS\\Fonts\\YuGothM.ttc',
#  'C:\\Windows\\Fonts\\msyi.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-Bold.ttf',
#  'C:\\Windows\\Fonts\\mmrtext.ttf',
#  'C:\\Windows\\Fonts\\CENSCBK.TTF',
#  'C:\\Windows\\Fonts\\seguibl.ttf',
#  'C:\\Windows\\Fonts\\ITCEDSCR.TTF',
#  'C:\\Windows\\Fonts\\ARIALNBI.TTF',
#  'C:\\Windows\\Fonts\\FRAHV.TTF',
#  'C:\\Windows\\Fonts\\GillSansUltraBoNova.ttf',
#  'C:\\Windows\\Fonts\\ArialNova.ttf',
#  'C:\\Windows\\Fonts\\LBRITEI.TTF',
#  'C:\\WINDOWS\\Fonts\\taileb.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuii.ttf',
#  'C:\\Windows\\Fonts\\BOD_BI.TTF',
#  'C:\\Windows\\Fonts\\GeorgiaPro-Regular.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-CondLightItalic.ttf',
#  'C:\\Windows\\Fonts\\GillSansCondUltraBoNova.ttf',
#  'C:\\Windows\\Fonts\\HMFMPYUN.TTF',
#  'C:\\Windows\\Fonts\\cordia.ttc',
#  'C:\\WINDOWS\\Fonts\\STSONG.TTF',
#  'C:\\Windows\\Fonts\\SCHLBKI.TTF',
#  'C:\\WINDOWS\\Fonts\\upcdb.ttf',
#  'C:\\Windows\\Fonts\\GLSNECB.TTF',
#  'C:\\WINDOWS\\Fonts\\rod.ttf',
#  'C:\\WINDOWS\\Fonts\\kokilab.ttf',
#  'C:\\Windows\\Fonts\\david.ttf',
#  'C:\\Windows\\Fonts\\gautami.ttf',
#  'C:\\Windows\\Fonts\\IMPRISHA.TTF',
#  'C:\\WINDOWS\\Fonts\\seguisbi.ttf',
#  'C:\\Windows\\Fonts\\STFANGSO.TTF',
#  'C:\\Windows\\Fonts\\HTOWERT.TTF',
#  'C:\\Windows\\Fonts\\times.ttf',
#  'C:\\WINDOWS\\Fonts\\Inkfree.ttf',
#  'C:\\Windows\\Fonts\\Orbitron-Bold.ttf',
#  'C:\\Windows\\Fonts\\utsaahi.ttf',
#  'C:\\WINDOWS\\Fonts\\Quicksand-Light.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-SemiBold.ttf',
#  'C:\\Windows\\Fonts\\BERNHC.TTF',
#  'C:\\Windows\\Fonts\\upcki.ttf',
#  'C:\\Windows\\Fonts\\KUNSTLER.TTF',
#  'C:\\WINDOWS\\Fonts\\FRAMDCN.TTF',
#  'C:\\WINDOWS\\Fonts\\H2GTRM.TTF',
#  'C:\\Windows\\Fonts\\ROCK.TTF',
#  'C:\\Windows\\Fonts\\DUBAI-LIGHT.TTF',
#  'C:\\WINDOWS\\Fonts\\ArialNovaCond-LightItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\upcib.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-Regular.ttf',
#  'C:\\Windows\\Fonts\\HMKMMAG.TTF',
#  'C:\\Windows\\Fonts\\simsun.ttc',
#  'C:\\WINDOWS\\Fonts\\ERASBD.TTF',
#  'C:\\Windows\\Fonts\\CALISTI.TTF',
#  'C:\\WINDOWS\\Fonts\\verdana.ttf',
#  'C:\\WINDOWS\\Fonts\\nyala.ttf',
#  'C:\\Windows\\Fonts\\BELL.TTF',
#  'C:\\WINDOWS\\Fonts\\BELLB.TTF',
#  'C:\\Windows\\Fonts\\Candarali.ttf',
#  'C:\\Windows\\Fonts\\himalaya.ttf',
#  'C:\\WINDOWS\\Fonts\\seguibli.ttf',
#  'C:\\WINDOWS\\Fonts\\Sanskr.ttf',
#  'C:\\Windows\\Fonts\\PERB____.TTF',
#  'C:\\Windows\\Fonts\\YuGothR.ttc',
#  'C:\\Windows\\Fonts\\gautamib.ttf',
#  'C:\\WINDOWS\\Fonts\\BRLNSR.TTF',
#  'C:\\WINDOWS\\Fonts\\GillSansCondLightItNova.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-CondLightItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\CALIFR.TTF',
#  'C:\\Windows\\Fonts\\GOTHIC.TTF',
#  'C:\\WINDOWS\\Fonts\\david.ttf',
#  'C:\\Windows\\Fonts\\seguili.ttf',
#  'C:\\WINDOWS\\Fonts\\iskpota.ttf',
#  'C:\\WINDOWS\\Fonts\\kokilabi.ttf',
#  'C:\\WINDOWS\\Fonts\\utsaahb.ttf',
#  'C:\\WINDOWS\\Fonts\\timesbd.ttf',
#  'C:\\WINDOWS\\Fonts\\RockwellNova-Italic.ttf',
#  'C:\\Windows\\Fonts\\BELLB.TTF',
#  'C:\\Windows\\Fonts\\ONYX.TTF',
#  'C:\\WINDOWS\\Fonts\\OCRAEXT.TTF',
#  'C:\\WINDOWS\\Fonts\\ArialNova-Light.ttf',
#  'C:\\Windows\\Fonts\\BowlbyOneSC-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\verdanai.ttf',
#  'C:\\WINDOWS\\Fonts\\arial.ttf',
#  'C:\\Windows\\Fonts\\timesbd.ttf',
#  'C:\\WINDOWS\\Fonts\\RockwellNova.ttf',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-SemiBoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\CENTURY.TTF',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-CondItalic.ttf',
#  'C:\\Windows\\Fonts\\ERASDEMI.TTF',
#  'C:\\Windows\\Fonts\\utsaahb.ttf',
#  'C:\\WINDOWS\\Fonts\\corbel.ttf',
#  'C:\\Windows\\Fonts\\msjhl.ttc',
#  'C:\\WINDOWS\\Fonts\\aldhabi.ttf',
#  'C:\\WINDOWS\\Fonts\\DUBAI-LIGHT.TTF',
#  'C:\\WINDOWS\\Fonts\\REFSPCL.TTF',
#  'C:\\WINDOWS\\Fonts\\kaiu.ttf',
#  'C:\\WINDOWS\\Fonts\\NHaasGroteskTXPro-It.ttf',
#  'C:\\WINDOWS\\Fonts\\ERASMD.TTF',
#  'C:\\Windows\\Fonts\\CHILLER.TTF',
#  'C:\\WINDOWS\\Fonts\\verdanab.ttf',
#  'C:\\Windows\\Fonts\\Dengb.ttf',
#  'C:\\WINDOWS\\Fonts\\arabtype.ttf',
#  'C:\\WINDOWS\\Fonts\\seguili.ttf',
#  'C:\\Windows\\Fonts\\meiryob.ttc',
#  'C:\\WINDOWS\\Fonts\\BOD_I.TTF',
#  'C:\\WINDOWS\\Fonts\\HMKMMAG.TTF',
#  'C:\\Windows\\Fonts\\GeorgiaPro-SemiBoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\upclb.ttf',
#  'C:\\Windows\\Fonts\\MAIAN.TTF',
#  'C:\\Windows\\Fonts\\tahomabd.ttf',
#  'C:\\Windows\\Fonts\\msgothic.ttc',
#  'C:\\WINDOWS\\Fonts\\SCHLBKBI.TTF',
#  'C:\\Windows\\Fonts\\vrindab.ttf',
#  'C:\\Windows\\Fonts\\Candara.ttf',
#  'C:\\WINDOWS\\Fonts\\GILI____.TTF',
#  'C:\\WINDOWS\\Fonts\\ANTQUABI.TTF',
#  'C:\\WINDOWS\\Fonts\\leelawad.ttf',
#  'C:\\Windows\\Fonts\\ARIALNI.TTF',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-CondSemiBold.ttf',
#  'C:\\Windows\\Fonts\\Cinzel-Black.ttf',
#  'C:\\Windows\\Fonts\\STLITI.TTF',
#  'C:\\WINDOWS\\Fonts\\calibri.ttf',
#  'C:\\WINDOWS\\Fonts\\ArialNova.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-Black.ttf',
#  'C:\\Windows\\Fonts\\FTLTLT.TTF',
#  'C:\\WINDOWS\\Fonts\\BSSYM7.TTF',
#  'C:\\Windows\\Fonts\\ANTQUAI.TTF',
#  'C:\\WINDOWS\\Fonts\\upclbi.ttf',
#  'C:\\WINDOWS\\Fonts\\mriamc.ttf',
#  'C:\\Windows\\Fonts\\H2PORL.TTF',
#  'C:\\Windows\\Fonts\\SCHLBKB.TTF',
#  'C:\\WINDOWS\\Fonts\\upcfi.ttf',
#  'C:\\Windows\\Fonts\\HMFMMUEX.TTC',
#  'C:\\Windows\\Fonts\\GeorgiaPro-Light.ttf',
#  'C:\\WINDOWS\\Fonts\\NotoSans-Regular.ttf',
#  'C:\\Windows\\Fonts\\lvnm.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-Bold.ttf',
#  'C:\\Windows\\Fonts\\RockwellNovaCond-Bold.ttf',
#  'C:\\WINDOWS\\Fonts\\Nirmala.ttf',
#  'C:\\Windows\\Fonts\\RockwellNovaCond-BoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\Shonarb.ttf',
#  'C:\\Windows\\Fonts\\LTYPE.TTF',
#  'C:\\WINDOWS\\Fonts\\KUNSTLER.TTF',
#  'C:\\Windows\\Fonts\\consolab.ttf',
#  'C:\\WINDOWS\\Fonts\\JOKERMAN.TTF',
#  'C:\\WINDOWS\\Fonts\\LFAX.TTF',
#  'C:\\Windows\\Fonts\\Quicksand-Medium.ttf',
#  'C:\\WINDOWS\\Fonts\\NIAGENG.TTF',
#  'C:\\Windows\\Fonts\\verdana.ttf',
#  'C:\\Windows\\Fonts\\RockwellNova-LightItalic.ttf',
#  'C:\\Windows\\Fonts\\Limelight-Regular.ttf',
#  'C:\\Windows\\Fonts\\DoppioOne-Regular.ttf',
#  'C:\\Windows\\Fonts\\pala.ttf',
#  'C:\\WINDOWS\\Fonts\\GillSansItNova.ttf',
#  'C:\\Windows\\Fonts\\INFROMAN.TTF',
#  'C:\\WINDOWS\\Fonts\\ELEPHNT.TTF',
#  'C:\\Windows\\Fonts\\BOD_BLAI.TTF',
#  'C:\\WINDOWS\\Fonts\\yuminl.ttf',
#  'C:\\WINDOWS\\Fonts\\SIMLI.TTF',
#  'C:\\Windows\\Fonts\\segoeuii.ttf',
#  'C:\\WINDOWS\\Fonts\\H2PORL.TTF',
#  'C:\\WINDOWS\\Fonts\\YuGothB.ttc',
#  'C:\\WINDOWS\\Fonts\\tradbdo.ttf',
#  'C:\\WINDOWS\\Fonts\\PERTILI.TTF',
#  'C:\\Windows\\Fonts\\ARLRDBD.TTF',
#  'C:\\WINDOWS\\Fonts\\CALISTI.TTF',
#  'C:\\WINDOWS\\Fonts\\GLECB.TTF',
#  'C:\\WINDOWS\\Fonts\\H2GPRM.TTF',
#  'C:\\WINDOWS\\Fonts\\consolai.ttf',
#  'C:\\WINDOWS\\Fonts\\BRLNSDB.TTF',
#  'C:\\Windows\\Fonts\\FRADMIT.TTF',
#  'C:\\WINDOWS\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\GARABD.TTF',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondSemiBold.ttf',
#  'C:\\WINDOWS\\Fonts\\cordia.ttc',
#  'C:\\WINDOWS\\Fonts\\FZYTK.TTF',
#  'C:\\Windows\\Fonts\\H2MJSM.TTF',
#  'C:\\WINDOWS\\Fonts\\GOTHICB.TTF',
#  'C:\\WINDOWS\\Fonts\\upcdbi.ttf',
#  'C:\\Windows\\Fonts\\GillSansCondBoItNova.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuib.ttf',
#  'C:\\WINDOWS\\Fonts\\corbelz.ttf',
#  'C:\\WINDOWS\\Fonts\\javatext.ttf',
#  'C:\\Windows\\Fonts\\cambriai.ttf',
#  'C:\\Windows\\Fonts\\ArialNovaCond-BoldItalic.ttf',
#  'C:\\Windows\\Fonts\\SIMYOU.TTF',
#  'C:\\Windows\\Fonts\\KhmerUI.ttf',
#  'C:\\Windows\\Fonts\\calibriz.ttf',
#  'C:\\WINDOWS\\Fonts\\YuGothR.ttc',
#  'C:\\Windows\\Fonts\\UrdType.ttf',
#  'C:\\Windows\\Fonts\\LTYPEB.TTF',
#  'C:\\Windows\\Fonts\\STXINWEI.TTF',
#  'C:\\WINDOWS\\Fonts\\malgunbd.ttf',
#  'C:\\WINDOWS\\Fonts\\Gabriola.ttf',
#  'C:\\WINDOWS\\Fonts\\STCAIYUN.TTF',
#  'C:\\WINDOWS\\Fonts\\cour.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-Light.ttf',
#  'C:\\WINDOWS\\Fonts\\angsana.ttc',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\Windows\\Fonts\\PARCHM.TTF',
#  'C:\\WINDOWS\\Fonts\\mingliub.ttc',
#  'C:\\WINDOWS\\Fonts\\VLADIMIR.TTF',
#  'C:\\WINDOWS\\Fonts\\GreatVibes-Regular.ttf',
#  'C:\\Windows\\Fonts\\H2HDRM.TTF',
#  'C:\\Windows\\Fonts\\BROADW.TTF',
#  'C:\\WINDOWS\\Fonts\\ROCK.TTF',
#  'C:\\Windows\\Fonts\\ARIALN.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_BLAR.TTF',
#  'C:\\WINDOWS\\Fonts\\UbuntuMono-Bold.ttf',
#  'C:\\WINDOWS\\Fonts\\CURLZ___.TTF',
#  'C:\\WINDOWS\\Fonts\\shrutib.ttf',
#  'C:\\WINDOWS\\Fonts\\simpbdo.ttf',
#  'C:\\Windows\\Fonts\\mangalb.ttf',
#  'C:\\Windows\\Fonts\\LeelUIsl.ttf',
#  'C:\\WINDOWS\\Fonts\\GillSansBoNova.ttf',
#  'C:\\WINDOWS\\Fonts\\andlso.ttf',
#  'C:\\Windows\\Fonts\\PERTILI.TTF',
#  'C:\\WINDOWS\\Fonts\\msuighub.ttf',
#  'C:\\WINDOWS\\Fonts\\upcjb.ttf',
#  'C:\\Windows\\Fonts\\LBRITEDI.TTF',
#  'C:\\Windows\\Fonts\\SitkaVF.ttf',
#  'C:\\WINDOWS\\Fonts\\GIGI.TTF',
#  'C:\\Windows\\Fonts\\GILBI___.TTF',
#  'C:\\WINDOWS\\Fonts\\arialbi.ttf',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-Italic.ttf',
#  'C:\\WINDOWS\\Fonts\\GillSansLightItNova.ttf',
#  'C:\\WINDOWS\\Fonts\\cambriab.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-Light.ttf',
#  'C:\\Windows\\Fonts\\LSANSI.TTF',
#  'C:\\WINDOWS\\Fonts\\HMKMAMI.TTF',
#  'C:\\Windows\\Fonts\\SitkaVF-Italic.ttf',
#  'C:\\Windows\\Fonts\\GIL_____.TTF',
#  'C:\\Windows\\Fonts\\javatext.ttf',
#  'C:\\WINDOWS\\Fonts\\moolbor.ttf',
#  'C:\\Windows\\Fonts\\upcebi.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-BlackItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\ERASDEMI.TTF',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-CondBlackItalic.ttf',
#  'C:\\Windows\\Fonts\\calibril.ttf',
#  'C:\\Windows\\Fonts\\STKAITI.TTF',
#  'C:\\Windows\\Fonts\\angsana.ttc',
#  'C:\\Windows\\Fonts\\CALIFI.TTF',
#  'C:\\Windows\\Fonts\\BELLI.TTF',
#  'C:\\WINDOWS\\Fonts\\ARIALNB.TTF',
#  'C:\\Windows\\Fonts\\BRADHITC.TTF',
#  'C:\\WINDOWS\\Fonts\\STZHONGS.TTF',
#  'C:\\Windows\\Fonts\\msuighur.ttf',
#  'C:\\Windows\\Fonts\\gadugi.ttf',
#  'C:\\WINDOWS\\Fonts\\TCB_____.TTF',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-CondBoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-CondLightItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\ITCKRIST.TTF',
#  'C:\\WINDOWS\\Fonts\\lvnmbd.ttf',
#  'C:\\WINDOWS\\Fonts\\comic.ttf',
#  'C:\\WINDOWS\\Fonts\\dokchamp.ttf',
#  'C:\\WINDOWS\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\UDDigiKyokashoN-B.ttc',
#  'C:\\Windows\\Fonts\\SHOWG.TTF',
#  'C:\\WINDOWS\\Fonts\\RockwellNova-Bold.ttf',
#  'C:\\WINDOWS\\Fonts\\PERI____.TTF',
#  'C:\\Windows\\Fonts\\H2GTRE.TTF',
#  'C:\\WINDOWS\\Fonts\\times.ttf',
#  'C:\\WINDOWS\\Fonts\\vrinda.ttf',
#  'C:\\WINDOWS\\Fonts\\LBRITED.TTF',
#  'C:\\Windows\\Fonts\\segoesc.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-CondItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\Dengb.ttf',
#  'C:\\WINDOWS\\Fonts\\SCHLBKB.TTF',
#  'C:\\WINDOWS\\Fonts\\msjhbd.ttc',
#  'C:\\Windows\\Fonts\\wingding.ttf',
#  'C:\\WINDOWS\\Fonts\\l_10646.ttf',
#  'C:\\Windows\\Fonts\\ENGR.TTF',
#  'C:\\Windows\\Fonts\\VIVALDII.TTF',
#  'C:\\WINDOWS\\Fonts\\Inter-Regular-slnt=0.ttf',
#  'C:\\Windows\\Fonts\\seguiemj.ttf',
#  'C:\\Windows\\Fonts\\FORTE.TTF',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-CondBlackItalic.ttf',
#  'C:\\Windows\\Fonts\\REFSPCL.TTF',
#  'C:\\Windows\\Fonts\\PER_____.TTF',
#  'C:\\Windows\\Fonts\\latha.ttf',
#  'C:\\WINDOWS\\Fonts\\upcei.ttf',
#  'C:\\Windows\\Fonts\\utsaahbi.ttf',
#  'C:\\WINDOWS\\Fonts\\H2HDRM.TTF',
#  'C:\\Windows\\Fonts\\consola.ttf',
#  'C:\\WINDOWS\\Fonts\\VIVALDII.TTF',
#  'C:\\Windows\\Fonts\\upckbi.ttf',
#  'C:\\WINDOWS\\Fonts\\DUBAI-MEDIUM.TTF',
#  'C:\\Windows\\Fonts\\tradbdo.ttf',
#  'C:\\Windows\\Fonts\\plantc.ttf',
#  'C:\\WINDOWS\\Fonts\\Vani.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondLightItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\BOD_BLAI.TTF',
#  'C:\\WINDOWS\\Fonts\\ONYX.TTF',
#  'C:\\Windows\\Fonts\\impact.ttf',
#  'C:\\Windows\\Fonts\\ebrima.ttf',
#  'C:\\Windows\\Fonts\\kokilab.ttf',
#  'C:\\Windows\\Fonts\\browalia.ttc',
#  'C:\\WINDOWS\\Fonts\\ariblk.ttf',
#  'C:\\WINDOWS\\Fonts\\HMFMOLD.TTF',
#  'C:\\WINDOWS\\Fonts\\CALIFI.TTF',
#  'C:\\Windows\\Fonts\\aldhabi.ttf',
#  'C:\\Windows\\Fonts\\NirmalaB.ttf',
#  'C:\\Windows\\Fonts\\calibrii.ttf',
#  'C:\\Windows\\Fonts\\LATINWD.TTF',
#  'C:\\Windows\\Fonts\\UrdTypeb.ttf',
#  'C:\\Windows\\Fonts\\ArialNova-Italic.ttf',
#  'C:\\Windows\\Fonts\\georgiaz.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondLight.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-CondRegular.ttf',
#  'C:\\Windows\\Fonts\\Shonar.ttf',
#  'C:\\WINDOWS\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'C:\\WINDOWS\\Fonts\\arialbd.ttf',
#  'C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\WINDOWS\\Fonts\\Yellowtail-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-SemiBoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\FREESCPT.TTF',
#  'C:\\Windows\\Fonts\\CALIFR.TTF',
#  'C:\\WINDOWS\\Fonts\\calibril.ttf',
#  'C:\\WINDOWS\\Fonts\\upcli.ttf',
#  'C:\\WINDOWS\\Fonts\\GillSansUltraBoNova.ttf',
#  'C:\\Windows\\Fonts\\RAGE.TTF',
#  'C:\\WINDOWS\\Fonts\\meiryo.ttc',
#  'C:\\WINDOWS\\Fonts\\SigmarOne-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\palab.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-SemiBoldItalic.ttf',
#  'C:\\Windows\\Fonts\\TCMI____.TTF',
#  'C:\\WINDOWS\\Fonts\\NotoSans-Bold.ttf',
#  'C:\\WINDOWS\\Fonts\\LATINWD.TTF',
#  'C:\\Windows\\Fonts\\gisha.ttf',
#  'C:\\WINDOWS\\Fonts\\CALIST.TTF',
#  'C:\\Windows\\Fonts\\segoeui.ttf',
#  'C:\\Windows\\Fonts\\Candaraz.ttf',
#  'C:\\Windows\\Fonts\\H2MJRE.TTF',
#  'C:\\Windows\\Fonts\\DUBAI-MEDIUM.TTF',
#  'C:\\WINDOWS\\Fonts\\vijayab.ttf',
#  'C:\\WINDOWS\\Fonts\\sylfaen.ttf',
#  'C:\\Windows\\Fonts\\kaiu.ttf',
#  'C:\\Windows\\Fonts\\calibrib.ttf',
#  'C:\\WINDOWS\\Fonts\\OLDENGL.TTF',
#  'C:\\WINDOWS\\Fonts\\kokilai.ttf',
#  'C:\\WINDOWS\\Fonts\\GIL_____.TTF',
#  'C:\\Windows\\Fonts\\lvnmbd.ttf',
#  'C:\\WINDOWS\\Fonts\\BROADW.TTF',
#  'C:\\Windows\\Fonts\\GeorgiaPro-LightItalic.ttf',
#  'C:\\Windows\\Fonts\\majalla.ttf',
#  'C:\\Windows\\Fonts\\kokila.ttf',
#  'C:\\WINDOWS\\Fonts\\LTYPE.TTF',
#  'C:\\WINDOWS\\Fonts\\marlett.ttf',
#  'C:\\Windows\\Fonts\\GILC____.TTF',
#  'C:\\Windows\\Fonts\\BOD_CB.TTF',
#  'C:\\Windows\\Fonts\\constanb.ttf',
#  'C:\\Windows\\Fonts\\LFAX.TTF',
#  'C:\\WINDOWS\\Fonts\\ebrimabd.ttf',
#  'C:\\WINDOWS\\Fonts\\taile.ttf',
#  'C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\GillSansCondLightItNova.ttf',
#  'C:\\Windows\\Fonts\\GOUDYSTO.TTF',
#  'C:\\WINDOWS\\Fonts\\impact.ttf',
#  'C:\\Windows\\Fonts\\Kalam-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\segmdl2.ttf',
#  'C:\\WINDOWS\\Fonts\\TCBI____.TTF',
#  'C:\\WINDOWS\\Fonts\\GillSansCondUltraBoNova.ttf',
#  'C:\\WINDOWS\\Fonts\\BOD_R.TTF',
#  'C:\\WINDOWS\\Fonts\\GOUDOSI.TTF',
#  'C:\\WINDOWS\\Fonts\\DUBAI-REGULAR.TTF',
#  'C:\\WINDOWS\\Fonts\\aparaji.ttf',
#  'C:\\Windows\\Fonts\\vijaya.ttf',
#  'C:\\Windows\\Fonts\\FRABKIT.TTF',
#  'C:\\Windows\\Fonts\\ELEPHNT.TTF',
#  'C:\\Windows\\Fonts\\palai.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-BlackItalic.ttf',
#  'C:\\Windows\\Fonts\\CALISTBI.TTF',
#  'C:\\WINDOWS\\Fonts\\ROCKEB.TTF',
#  'C:\\WINDOWS\\Fonts\\HTOWERTI.TTF',
#  'C:\\WINDOWS\\Fonts\\GOUDYSTO.TTF',
#  'C:\\WINDOWS\\Fonts\\SNAP____.TTF',
#  'C:\\Windows\\Fonts\\palabi.ttf',
#  'C:\\Windows\\Fonts\\comic.ttf',
#  'C:\\WINDOWS\\Fonts\\courbi.ttf',
#  'C:\\WINDOWS\\Fonts\\phagspab.ttf',
#  'C:\\WINDOWS\\Fonts\\BAUHS93.TTF',
#  'C:\\WINDOWS\\Fonts\\BIZ-UDMinchoM.ttc',
#  'C:\\Windows\\Fonts\\MTEXTRA.TTF',
#  'C:\\Windows\\Fonts\\upcji.ttf',
#  'C:\\Windows\\Fonts\\constanz.ttf',
#  'C:\\Windows\\Fonts\\BKANT.TTF',
#  'C:\\WINDOWS\\Fonts\\lvnm.ttf',
#  'C:\\WINDOWS\\Fonts\\lathab.ttf',
#  'C:\\Windows\\Fonts\\webdings.ttf',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-CondSemiBold.ttf',
#  'C:\\Windows\\Fonts\\ahronbd.ttf',
#  'C:\\WINDOWS\\Fonts\\yumin.ttf',
#  'C:\\WINDOWS\\Fonts\\TCCM____.TTF',
#  'C:\\Windows\\Fonts\\POORICH.TTF',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondBoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\GillSansCondBoItNova.ttf',
#  'C:\\Windows\\Fonts\\GillSansCondBoNova.ttf',
#  'C:\\Windows\\Fonts\\msjhbd.ttc',
#  'C:\\Windows\\Fonts\\cambria.ttc',
#  'C:\\WINDOWS\\Fonts\\FRADMCN.TTF',
#  'C:\\Windows\\Fonts\\ITCBLKAD.TTF',
#  'C:\\WINDOWS\\Fonts\\CENTAUR.TTF',
#  'C:\\Windows\\Fonts\\RockwellNovaCond-Light.ttf',
#  'C:\\WINDOWS\\Fonts\\BRLNSB.TTF',
#  'C:\\WINDOWS\\Fonts\\GillSansLightNova.ttf',
#  'C:\\Windows\\Fonts\\TCM_____.TTF',
#  'C:\\Windows\\Fonts\\MISTRAL.TTF',
#  'C:\\WINDOWS\\Fonts\\trebucit.ttf',
#  'C:\\Windows\\Fonts\\raavib.ttf',
#  'C:\\Windows\\Fonts\\BOOKOS.TTF',
#  'C:\\WINDOWS\\Fonts\\leelawdb.ttf',
#  'C:\\WINDOWS\\Fonts\\COPRGTB.TTF',
#  'C:\\WINDOWS\\Fonts\\aparaj.ttf',
#  'C:\\Windows\\Fonts\\REFSAN.TTF',
#  'C:\\Windows\\Fonts\\consolai.ttf',
#  'C:\\WINDOWS\\Fonts\\STXIHEI.TTF',
#  'C:\\Windows\\Fonts\\seguisli.ttf',
#  'C:\\Windows\\Fonts\\iskpota.ttf',
#  'C:\\WINDOWS\\Fonts\\Dengl.ttf',
#  'C:\\WINDOWS\\Fonts\\RockwellNovaCond-LightItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeuisl.ttf',
#  'C:\\Windows\\Fonts\\ANTQUAB.TTF',
#  'C:\\WINDOWS\\Fonts\\msmincho.ttc',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-BlackItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\vijaya.ttf',
#  'C:\\Windows\\Fonts\\WINGDNG3.TTF',
#  'C:\\Windows\\Fonts\\aparajbi.ttf',
#  'C:\\Windows\\Fonts\\NotoSans-Italic.ttf',
#  'C:\\WINDOWS\\Fonts\\HARNGTON.TTF',
#  'C:\\Windows\\Fonts\\upcdb.ttf',
#  'C:\\WINDOWS\\Fonts\\CALIFB.TTF',
#  'C:\\WINDOWS\\Fonts\\RussoOne-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\H2GTRE.TTF',
#  'C:\\Windows\\Fonts\\UbuntuMono-Regular.ttf',
#  'C:\\Windows\\Fonts\\ebrimabd.ttf',
#  'C:\\Windows\\Fonts\\symbol.ttf',
#  'C:\\WINDOWS\\Fonts\\COLONNA.TTF',
#  'C:\\Windows\\Fonts\\segoeuisl.ttf',
#  'C:\\Windows\\Fonts\\LBRITE.TTF',
#  'C:\\Windows\\Fonts\\iskpotab.ttf',
#  'C:\\Windows\\Fonts\\timesi.ttf',
#  'C:\\WINDOWS\\Fonts\\H2PORM.TTF',
#  'C:\\WINDOWS\\Fonts\\upcel.ttf',
#  'C:\\WINDOWS\\Fonts\\seguiemj.ttf',
#  'C:\\WINDOWS\\Fonts\\georgiab.ttf',
#  'C:\\WINDOWS\\Fonts\\ANTQUAB.TTF',
#  'C:\\WINDOWS\\Fonts\\upcji.ttf',
#  'C:\\WINDOWS\\Fonts\\PERTIBD.TTF',
#  'C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\WINDOWS\\Fonts\\FRSCRIPT.TTF',
#  'C:\\WINDOWS\\Fonts\\STXINWEI.TTF',
#  'C:\\Windows\\Fonts\\ariblk.ttf',
#  'C:\\Windows\\Fonts\\andlso.ttf',
#  'C:\\WINDOWS\\Fonts\\Orbitron-Bold.ttf',
#  'C:\\Windows\\Fonts\\upckl.ttf',
#  'C:\\WINDOWS\\Fonts\\ntailub.ttf',
#  'C:\\WINDOWS\\Fonts\\UrdTypeb.ttf',
#  'C:\\Windows\\Fonts\\seguihis.ttf',
#  'C:\\Windows\\Fonts\\mingliu.ttc',
#  'C:\\Windows\\Fonts\\LaoUI.ttf',
#  'C:\\WINDOWS\\Fonts\\Kalam-Bold.ttf',
#  'C:\\Windows\\Fonts\\vrinda.ttf',
#  'C:\\Windows\\Fonts\\COPRGTB.TTF',
#  'C:\\WINDOWS\\Fonts\\PER_____.TTF',
#  'C:\\Windows\\Fonts\\lathab.ttf',
#  'C:\\WINDOWS\\Fonts\\Quicksand-Bold.ttf',
#  'C:\\Windows\\Fonts\\trebucbi.ttf',
#  'C:\\WINDOWS\\Fonts\\msyh.ttc',
#  'C:\\WINDOWS\\Fonts\\comicbd.ttf',
#  'C:\\WINDOWS\\Fonts\\GOTHICBI.TTF',
#  'C:\\WINDOWS\\Fonts\\POORICH.TTF',
#  'C:\\WINDOWS\\Fonts\\tungab.ttf',
#  'C:\\Windows\\Fonts\\GILSANUB.TTF',
#  'C:\\Windows\\Fonts\\ArialNova-BoldItalic.ttf',
#  'C:\\Windows\\Fonts\\ERASLGHT.TTF',
#  'C:\\Windows\\Fonts\\upcei.ttf',
#  'C:\\Windows\\Fonts\\GARA.TTF',
#  'C:\\Windows\\Fonts\\PAPYRUS.TTF',
#  'C:\\WINDOWS\\Fonts\\LaoUIb.ttf',
#  'C:\\WINDOWS\\Fonts\\seguihis.ttf',
#  'C:\\Windows\\Fonts\\PermanentMarker.ttf',
#  'C:\\Windows\\Fonts\\upcfbi.ttf',
#  'C:\\Windows\\Fonts\\FRABK.TTF',
#  'C:\\WINDOWS\\Fonts\\MTEXTRA.TTF',
#  'C:\\WINDOWS\\Fonts\\RockwellNovaCond-Light.ttf',
#  'C:\\WINDOWS\\Fonts\\upcii.ttf',
#  'C:\\WINDOWS\\Fonts\\GILSANUB.TTF',
#  'C:\\Windows\\Fonts\\meiryo.ttc',
#  'C:\\Windows\\Fonts\\mriamc.ttf',
#  'C:\\Windows\\Fonts\\GillSansItNova.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-Italic.ttf',
#  'C:\\Windows\\Fonts\\RockwellNovaCond-LightItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\lucon.ttf',
#  'C:\\WINDOWS\\Fonts\\SIMYOU.TTF',
#  'C:\\Windows\\Fonts\\NHaasGroteskTXPro-Rg.ttf',
#  'C:\\WINDOWS\\Fonts\\STLITI.TTF',
#  'C:\\WINDOWS\\Fonts\\LTYPEBO.TTF',
#  'C:\\Windows\\Fonts\\sylfaen.ttf',
#  'C:\\Windows\\Fonts\\PERI____.TTF',
#  'C:\\WINDOWS\\Fonts\\LBRITEI.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_CBI.TTF',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondItalic.ttf',
#  'C:\\Windows\\Fonts\\BOD_I.TTF',
#  'C:\\WINDOWS\\Fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\STENCIL.TTF',
#  'C:\\Windows\\Fonts\\seguisbi.ttf',
#  'C:\\Windows\\Fonts\\TCCB____.TTF',
#  'C:\\WINDOWS\\Fonts\\FORTE.TTF',
#  'C:\\WINDOWS\\Fonts\\timesi.ttf',
#  'C:\\WINDOWS\\Fonts\\ROCC____.TTF',
#  'C:\\WINDOWS\\Fonts\\gisha.ttf',
#  'C:\\WINDOWS\\Fonts\\webdings.ttf',
#  'C:\\WINDOWS\\Fonts\\GillSansCondItNova.ttf',
#  'C:\\Windows\\Fonts\\raavi.ttf',
#  'C:\\Windows\\Fonts\\batang.ttc',
#  'C:\\WINDOWS\\Fonts\\ArialNova-Bold.ttf',
#  'C:\\Windows\\Fonts\\cambriab.ttf',
#  'C:\\WINDOWS\\Fonts\\ITCBLKAD.TTF',
#  'C:\\WINDOWS\\Fonts\\FREESCPT.TTF',
#  'C:\\WINDOWS\\Fonts\\kokila.ttf',
#  'C:\\WINDOWS\\Fonts\\LSANS.TTF',
#  'C:\\Windows\\Fonts\\CabinSketch-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\BIZ-UDGothicB.ttc',
#  'C:\\WINDOWS\\Fonts\\constan.ttf',
#  'C:\\WINDOWS\\Fonts\\ROCKBI.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_CR.TTF',
#  'C:\\WINDOWS\\Fonts\\H2SA1M.TTF',
#  'C:\\Windows\\Fonts\\seguibli.ttf',
#  'C:\\Windows\\Fonts\\H2GSRB.TTF',
#  'C:\\WINDOWS\\Fonts\\segoescb.ttf',
#  'C:\\Windows\\Fonts\\upcfl.ttf',
#  'C:\\Windows\\Fonts\\JOKERMAN.TTF',
#  'C:\\Windows\\Fonts\\BOOKOSI.TTF',
#  'C:\\Windows\\Fonts\\FRAMDCN.TTF',
#  'C:\\Windows\\Fonts\\monbaiti.ttf',
#  'C:\\WINDOWS\\Fonts\\GillSansNova.ttf',
#  'C:\\WINDOWS\\Fonts\\nrkis.ttf',
#  'C:\\Windows\\Fonts\\upcll.ttf',
#  'C:\\Windows\\Fonts\\FRSCRIPT.TTF',
#  'C:\\WINDOWS\\Fonts\\ntailu.ttf',
#  'C:\\Windows\\Fonts\\upcjl.ttf',
#  'C:\\Windows\\Fonts\\FRADM.TTF',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-CondSemiBoldItalic.ttf',
#  'C:\\Windows\\Fonts\\H2MKPB.TTF',
#  'C:\\WINDOWS\\Fonts\\msjhl.ttc',
#  'C:\\WINDOWS\\Fonts\\comicz.ttf',
#  'C:\\Windows\\Fonts\\CASTELAR.TTF',
#  'C:\\WINDOWS\\Fonts\\CASTELAR.TTF',
#  'C:\\Windows\\Fonts\\BRLNSR.TTF',
#  'C:\\WINDOWS\\Fonts\\kartika.ttf',
#  'C:\\Windows\\Fonts\\COPRGTL.TTF',
#  'C:\\WINDOWS\\Fonts\\TCMI____.TTF',
#  'C:\\Windows\\Fonts\\JUICE___.TTF',
#  'C:\\Windows\\Fonts\\BOD_CI.TTF',
#  'C:\\WINDOWS\\Fonts\\aparajb.ttf',
#  'C:\\WINDOWS\\Fonts\\GillSansCondNova.ttf',
#  'C:\\Windows\\Fonts\\GreatVibes-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\seguisb.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-CondBold.ttf',
#  'C:\\WINDOWS\\Fonts\\BRUSHSCI.TTF',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\WINDOWS\\Fonts\\TCCEB.TTF',
#  'C:\\WINDOWS\\Fonts\\gadugib.ttf',
#  'C:\\WINDOWS\\Fonts\\MOD20.TTF',
#  'C:\\WINDOWS\\Fonts\\yumindb.ttf',
#  'C:\\WINDOWS\\Fonts\\DoppioOne-Regular.ttf',
#  'C:\\Windows\\Fonts\\BAUHS93.TTF',
#  'C:\\Windows\\Fonts\\upcil.ttf',
#  'C:\\WINDOWS\\Fonts\\utsaahbi.ttf',
#  'C:\\Windows\\Fonts\\CENTAUR.TTF',
#  'C:\\WINDOWS\\Fonts\\FTLTLT.TTF',
#  'C:\\Windows\\Fonts\\VerdanaPro-BlackItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-CondBoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\PALSCRI.TTF',
#  'C:\\WINDOWS\\Fonts\\tunga.ttf',
#  'C:\\Windows\\Fonts\\unispace bd.ttf',
#  'C:\\Windows\\Fonts\\ROCC____.TTF',
#  'C:\\WINDOWS\\Fonts\\mmrtext.ttf',
#  'C:\\WINDOWS\\Fonts\\H2MJRE.TTF',
#  'C:\\WINDOWS\\Fonts\\Kalam-Light.ttf',
#  'C:\\Windows\\Fonts\\euphemia.ttf',
#  'C:\\WINDOWS\\Fonts\\trado.ttf',
#  'C:\\WINDOWS\\Fonts\\Quicksand-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\HARLOWSI.TTF',
#  'C:\\WINDOWS\\Fonts\\FRABKIT.TTF',
#  'C:\\Windows\\Fonts\\BOD_BLAR.TTF',
#  'C:\\WINDOWS\\Fonts\\comici.ttf',
#  'C:\\WINDOWS\\Fonts\\ArialNovaCond.ttf',
#  'C:\\WINDOWS\\Fonts\\upcdl.ttf',
#  'C:\\Users\\Noah\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic.ttf',
#  'C:\\Windows\\Fonts\\AGENCYB.TTF',
#  'C:\\Windows\\Fonts\\NIAGSOL.TTF',
#  'C:\\WINDOWS\\Fonts\\palabi.ttf',
#  'C:\\WINDOWS\\Fonts\\Candarab.ttf',
#  'C:\\Windows\\Fonts\\Courgette-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\Shrikhand-Regular.ttf',
#  'C:\\Windows\\Fonts\\estre.ttf',
#  'C:\\Windows\\Fonts\\simkai.ttf',
#  'C:\\WINDOWS\\Fonts\\framdit.ttf',
#  'C:\\Windows\\Fonts\\LBRITED.TTF',
#  'C:\\WINDOWS\\Fonts\\RockwellNovaCond-Bold.ttf',
#  'C:\\Windows\\Fonts\\LFAXI.TTF',
#  'C:\\WINDOWS\\Fonts\\upcil.ttf',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-CondBlack.ttf',
#  'C:\\Windows\\Fonts\\mmrtextb.ttf',
#  'C:\\Windows\\Fonts\\Deng.ttf',
#  'C:\\Windows\\Fonts\\Shrikhand-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\ebrima.ttf',
#  'C:\\WINDOWS\\Fonts\\CALISTB.TTF',
#  'C:\\Windows\\Fonts\\Nirmala.ttf',
#  'C:\\WINDOWS\\Fonts\\BOD_CB.TTF',
#  'C:\\Windows\\Fonts\\seguisb.ttf',
#  'C:\\Windows\\Fonts\\BOD_B.TTF',
#  'C:\\WINDOWS\\Fonts\\gishabd.ttf',
#  'C:\\Windows\\Fonts\\HMKMAMI.TTF',
#  'C:\\WINDOWS\\Fonts\\himalaya.ttf',
#  'C:\\WINDOWS\\Fonts\\BASKVILL.TTF',
#  'C:\\Windows\\Fonts\\Inter-Bold-slnt=0.ttf',
#  'C:\\Windows\\Fonts\\upcibi.ttf',
#  'C:\\WINDOWS\\Fonts\\seguibl.ttf',
#  'C:\\Windows\\Fonts\\BOOKOSB.TTF',
#  'C:\\Windows\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\tunga.ttf',
#  'C:\\Windows\\Fonts\\VerdanaPro-Black.ttf',
#  'C:\\WINDOWS\\Fonts\\COOPBL.TTF',
#  'C:\\Windows\\Fonts\\shruti.ttf',
#  'C:\\WINDOWS\\Fonts\\utsaahi.ttf',
#  'C:\\Windows\\Fonts\\NIAGENG.TTF',
#  'C:\\WINDOWS\\Fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\segoeuib.ttf',
#  'C:\\WINDOWS\\Fonts\\GillSansCondExtraNova.ttf',
#  'C:\\WINDOWS\\Fonts\\gadugi.ttf',
#  'C:\\WINDOWS\\Fonts\\segoeprb.ttf',
#  'C:\\WINDOWS\\Fonts\\georgiaz.ttf',
#  'C:\\WINDOWS\\Fonts\\Candaraz.ttf',
#  'C:\\WINDOWS\\Fonts\\majallab.ttf',
#  'C:\\WINDOWS\\Fonts\\H2GSRB.TTF',
#  'C:\\Windows\\Fonts\\BIZ-UDMinchoM.ttc',
#  'C:\\Windows\\Fonts\\MAGNETOB.TTF',
#  'C:\\Windows\\Fonts\\georgiai.ttf',
#  'C:\\Windows\\Fonts\\seguisym.ttf',
#  'C:\\WINDOWS\\Fonts\\VINERITC.TTF',
#  'C:\\WINDOWS\\Fonts\\ROGFonts-Regular.otf',
#  'C:\\Windows\\Fonts\\mriam.ttf',
#  'C:\\Windows\\Fonts\\LTYPEO.TTF',
#  'C:\\WINDOWS\\Fonts\\STHUPO.TTF',
#  'C:\\WINDOWS\\Fonts\\kartikab.ttf',
#  'C:\\Windows\\Fonts\\Lemon-Regular.ttf',
#  'C:\\Windows\\Fonts\\NHaasGroteskTXPro-It.ttf',
#  'C:\\Windows\\Fonts\\GILB____.TTF',
#  'C:\\Windows\\Fonts\\YuGothM.ttc',
#  'C:\\Windows\\Fonts\\RockwellNova-BoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\RAGE.TTF',
#  'C:\\WINDOWS\\Fonts\\TCM_____.TTF',
#  'C:\\Windows\\Fonts\\LCALLIG.TTF',
#  'C:\\WINDOWS\\Fonts\\ELEPHNTI.TTF',
#  'C:\\Windows\\Fonts\\GOUDOS.TTF',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-CondSemiBoldItalic.ttf',
#  'C:\\WINDOWS\\Fonts\\GeorgiaPro-Italic.ttf',
#  'C:\\Windows\\Fonts\\CALIFB.TTF',
#  'C:\\WINDOWS\\Fonts\\UDDigiKyokashoN-B.ttc',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\micross.ttf',
#  'C:\\WINDOWS\\Fonts\\GARA.TTF',
#  'C:\\WINDOWS\\Fonts\\LCALLIG.TTF',
#  'C:\\WINDOWS\\Fonts\\Candaral.ttf',
#  'C:\\WINDOWS\\Fonts\\verdanaz.ttf',
#  'C:\\Windows\\Fonts\\msuighub.ttf',
#  'C:\\WINDOWS\\Fonts\\upcdi.ttf',
#  'C:\\WINDOWS\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\BASKVILL.TTF',
#  'C:\\Windows\\Fonts\\SegoeIcons.ttf',
#  'C:\\WINDOWS\\Fonts\\JUICE___.TTF',
#  'C:\\Windows\\Fonts\\ntailub.ttf',
#  'C:\\WINDOWS\\Fonts\\ARIALNBI.TTF',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\HARNGTON.TTF',
#  'C:\\WINDOWS\\Fonts\\TCCB____.TTF',
#  'C:\\WINDOWS\\Fonts\\ArialNovaCond-Light.ttf',
#  'C:\\Windows\\Fonts\\BOD_CBI.TTF',
#  'C:\\Windows\\Fonts\\VLADIMIR.TTF',
#  'C:\\Windows\\Fonts\\FZYTK.TTF',
#  'C:\\WINDOWS\\Fonts\\PERBI___.TTF',
#  'C:\\Windows\\Fonts\\TCB_____.TTF',
#  'C:\\Windows\\Fonts\\GillSansLightItNova.ttf',
#  'C:\\WINDOWS\\Fonts\\Candara.ttf',
#  'C:\\Windows\\Fonts\\RockwellNova-ExtraBold.ttf',
#  'C:\\WINDOWS\\Fonts\\timesbi.ttf',
#  'C:\\Windows\\Fonts\\courbd.ttf',
#  'C:\\WINDOWS\\Fonts\\constanb.ttf',
#  'C:\\WINDOWS\\Fonts\\Cookie-Regular.ttf',
#  'C:\\Windows\\Fonts\\MarcellusSC-Regular.ttf',
#  'C:\\WINDOWS\\Fonts\\georgia.ttf',
#  'C:\\WINDOWS\\Fonts\\FRAHV.TTF',
#  'C:\\Windows\\Fonts\\yumindb.ttf',
#  'C:\\Windows\\Fonts\\simfang.ttf',
#  'C:\\WINDOWS\\Fonts\\BOOKOSBI.TTF',
#  'C:\\Windows\\Fonts\\upcel.ttf',
#  'C:\\Windows\\Fonts\\ArialNovaCond.ttf',
#  'C:\\WINDOWS\\Fonts\\GILB____.TTF',
#  'C:\\WINDOWS\\Fonts\\NGULIM.TTF',
#  'C:\\WINDOWS\\Fonts\\upckbi.ttf',
#  'C:\\Windows\\Fonts\\HARLOWSI.TTF',
#  'C:\\WINDOWS\\Fonts\\CALISTBI.TTF',
#  'C:\\Windows\\Fonts\\BOD_R.TTF',
#  'C:\\WINDOWS\\Fonts\\VerdanaPro-Black.ttf',
#  'C:\\WINDOWS\\Fonts\\UbuntuMono-Regular.ttf',
#  'C:\\Windows\\Fonts\\leelawad.ttf',
#  'C:\\WINDOWS\\Fonts\\H2MKPB.TTF',
#  'C:\\WINDOWS\\Fonts\\REFSAN.TTF',
#  ...]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(0)

# 한글 지원 폰트
plt.figure(figsize=(15, 10))
sns.set(font='NanumGothic')

# sns.set으로만 폰트 호출이 되지 않을때 아래 방법으로 사용.
#font_location = 'C:/Users/Noah/AppData/Local/Microsoft/Windows/Fonts/NanumGothic.ttf'  
#font_name = fm.FontProperties(fname=font_location).get_name()
#sns.set(font=font_name)


# 마이너스 부호 

plt.rcParams['axes.unicode_minus'] = False

ax = sns.heatmap(matrix, xticklabels=genre_name, yticklabels=genre_name, linewidths=.5, annot=True, cmap="RdYlGn_r")
ax
# Out:
# <AxesSubplot:>

# %% [markdown]
# - seaborn.heatmap(data, xticklabels, yticklabels, annot, cmap)
#     data : rectangular dataset
#     xticklabels, yticklabels : list-like, plot these alternate labels as the xticklabels
#     annot=True : write the data value in each cell
#     cmap : The mapping from data values to color space
#     https://seaborn.pydata.org/generated/seaborn.heatmap.html
#
# WEAT score가 0.8 이상이거나 -0.8 이하인 관계만 따로 시각화 해봅니다.

# %%
matrix2 = [[0 for _ in range(len(genre_name))] for _ in range(len(genre_name))]

# %%
for i, j, score in over8:
    matrix2[i][j] = score
    
for i, j, score in under_8:
    matrix2[i][j] = score

# %%
np.random.seed(0)

# 한글 지원 폰트
plt.figure(figsize=(15, 10))
sns.set(font='NanumGothic')

# sns.set으로만 폰트 호출이 되지 않을때 아래 방법으로 사용.
#font_location = 'C:/Users/Noah/AppData/Local/Microsoft/Windows/Fonts/NanumGothic.ttf'  
#font_name = fm.FontProperties(fname=font_location).get_name()
#sns.set(font=font_name)

# 마이너스 부호 깨짐 현상이 일어날때 사용

plt.rcParams['axes.unicode_minus'] = False

ax = sns.heatmap(matrix2, xticklabels=genre_name, yticklabels=genre_name, linewidth=5, cmap='RdYlGn_r')
ax
# Out:
# <AxesSubplot:>

# %%
end_time = time.time()
work_time = round(end_time - start_time)
print(f'총 작업 소요 시간은 약 {work_time}초입니다.')
# Out:
# 총 작업 소요 시간은 약 993초입니다.

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\Noah\\anaconda3\\envs\\Aiffel2\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
matplotlib.get_cachedir()
# Out:
# 'C:\\Users\\Noah\\.matplotlib'

# %% [markdown]
# # 회고
#
# 1. 주어진 영화 코퍼스를 바탕으로 워드임베딩 모델을 정상적으로 만들었다.
#     - synopsis.txt(영화들의 시놉시스 정보)의 명사인 경우만 코퍼스로 저장하였다.
#     - 위의 코퍼스 데이터를 가지고 Word2Vec을 생성하였다.
#     - 워드임베딩의 most_similar() 메소드 결과가 의미상 바르게 나온것을 확인하였다.
#
#
# 2. 영화 구분, 장르별로 target, attribute에 대한 대표성있는 단어 셋을 생성하였다.
#     - TF-IDF를 사용하여 높은 순으로 해당 데이터를 가장 잘 표현하는 단어 셋을 만들었다.
#     - target의 단어 셋의 중복을 제거하여 개념축을 의미적으로 잘 대표하는 단어 셋이 만들어졌다.
#     - attribute의 단어 셋은 중복이 많이 겹치지 않으므로 중복을 제거하지 않고 그대로 사용하였다.
#
#
# 3. WEAT score 계산 및 시각화를 정상적으로 진행하였다.
#     - 전체 영화 장르별로 예술/일반 영화에 대한 편향성 WEAT score를 계산하였다.
#         WEAT score가 가장 큰 장르는 미스터리 범죄 (1.0349393)이였고,
#         WEAT score가 가장 작은 장르는 범죄 스릴러 (-0.966826)였다.
#     - WEAT score를 Heatmap으로 잘 시각화하였다.

# %% [markdown]
# # 한글폰트가 자꾸 깨져서 고생을 했다..
#
# ## matplotlib 한글 폰트 사용하기 + Font family [] not found 에러 해결방법
#
# Font family [] not found. Falling back to DejaVu Sans 에러의 경우 4번부터 시작
#
# ### 1. 폰트 디렉토리 위치 찾기는 아래코드 사용.
#
# import matplotlib
# matplotlib.matplotlib_fname()
#
# ### 2. mpl-data 디렉토리로 이동
#
# matplotlibrc 파일을 실행(메모장)
#
# 나 같은경우는 `C:\Users\Noah\anaconda3\envs\Aiffel2\Lib\site-packages\matplotlib\mpl-data\fonts\ttf` 경로에 직접 넣어줬으며,
#
# 이것이 끝이아니다. `C:\Users\Noah\anaconda3\envs\Aiffel2\Lib\site-packages\matplotlib\mpl-data`경로 폴더를 보면
#
# "matplotlibrc" 파일을 메모장으로 열어서, Ctrl + F 를 이용하여 font.family 찾으면, 아래와 같이 되어 있는부분으로 간다.
#
# - #font.family:  `NanumGothic`  <<< 이부분에 사용하고자 하는 폰트명으로 수정 해준다.
# - #font.style:   normal
# - #font.variant: normal
# - #font.weight:  normal
# - #font.stretch: normal
# - #font.size:    10.0
#
#     1). 운영체제에도 해당 폰트가 있어야 한다.
#     2). 권한 문제로 수정이 안 되는 경우 matplotlibrc 파일 속성에서 사용 권한 수정
#
# ### 3. ttf 폴더에 NaumGothic.ttf 파일을 추가
#
# 경로에서 다이렉트로 불러오기도 해봤고, 폰트 설치시 C:/Windows/Font 경로에 설치되는게 아니라. 다른 경로에 저장이 되어있기 때문에,
#
# 문제가 되서 폰트가 깨지는건줄 알고, 별짓 다해봤지만 그런건 아니였다.
#
# anaconda로 가상환경을 NLP용 따로, EX용 따로, Datathon 따로 , 상황별로 가상환경을 만들어 놓다보니,
#
# 사용하고자 하는 가상환경 ttf 폴더에 직접 사용하고자 하는 폰트 ttf파일을 넣어줘야한다.
#
# ### 4. 캐쉬 경로 검색
# - matplotlib.get_cachedir()
#
# ### 5. 주피터 셧다운, 캐쉬 경로로 이동, tex.cache 폴더랑 fontList.json 파일 모두 삭제
#
# ### 6. 주피터 재실행

# %% [markdown]
# # 참고
# * [Konlpy Okt 공식홈페이지](https://konlpy.org/en/latest/api/konlpy.tag/)
# * [Konlpy 한국어 처리 패키지 - 데이터 사이언스 스쿨](https://datascienceschool.net/03%20machine%20learning/03.01.02%20KoNLPy%20%ED%95%9C%EA%B5%AD%EC%96%B4%20%EC%B2%98%EB%A6%AC%20%ED%8C%A8%ED%82%A4%EC%A7%80.html)
# * [Konlpy 예제 적용](https://truman.tistory.com/112)
# * [딥러닝을 이용한 자연어 처리 입문 - gensim Word2Vec](https://wikidocs.net/50739)
# * [gensim Word2Vec 적용방법](https://blog.naver.com/navehag/222322466815)
